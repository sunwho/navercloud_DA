# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.rcParams['font.family'] = 'AppleGothic'

# %%
boa1 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2301.xlsx')
boa2 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2302.xlsx')
boa3 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2303.xlsx')
boa4 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2304.xlsx')
boa5 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2305.xlsx')
boa6 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2306.xlsx')
boa7 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2307.xlsx')
boa8 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2308.xlsx')
boa9 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2309.xlsx')
boa10 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2310.xlsx')
boa11 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2311.xlsx')
boa12 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2312.xlsx')
boa13 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2401.xlsx')
boa14 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2402.xlsx')
boa15 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2403.xlsx')
boa16 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2404.xlsx')
boa17 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2405.xlsx')
boa18 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2406.xlsx')
boa19 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2407.xlsx')
boa20 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2408.xlsx')
boa21 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2409.xlsx')
boa22 = pd.read_excel('/Users/user/Documents/BOA 데이터/boa2410.xlsx')

# %%
boa22.loc[boa22['구분3']=='WORKS DRIVE','구분3'] = 'WORKBOX'
boa22.loc[boa22['상품명']=='웍스 드라이브 문서 공동 편집','구분3'] = 'NAVER WORKS'

# %%
od_works_1 = []
pt_works_1 = []
od_works_2 = []
pt_works_2 = []
od_box_1 = []
pt_box_1 = []
od_box_2 = []
pt_box_2 = []
od_place_1 = []
pt_place_1 = []
od_place_2 = []
pt_place_2 = []
boa2023 = [boa1, boa2, boa3, boa4, boa5, boa6, boa7, boa8, boa9, boa10, boa11, boa12]
for i in range(0,len(boa2023)) :
    od_works_1.append(boa2023[i][(boa2023[i]['채널']!='파트너 매출')&(boa2023[i]['구분3']=='NAVER WORKS')]['이용금액(당월)'].sum())
    pt_works_1.append(boa2023[i][(boa2023[i]['채널']=='파트너 매출')&(boa2023[i]['구분3']=='NAVER WORKS')]['이용금액(당월)'].sum())
    od_works_2.append(boa2023[i][(boa2023[i]['채널']!='파트너 매출')&(boa2023[i]['구분3']=='NAVER WORKS')]['매출금액(당월)'].sum())
    pt_works_2.append(boa2023[i][(boa2023[i]['채널']=='파트너 매출')&(boa2023[i]['구분3']=='NAVER WORKS')]['매출금액(당월)'].sum())
    od_box_1.append(boa2023[i][(boa2023[i]['채널']!='파트너 매출')&(boa2023[i]['구분3']=='WORKBOX')]['이용금액(당월)'].sum())
    pt_box_1.append(boa2023[i][(boa2023[i]['채널']=='파트너 매출')&(boa2023[i]['구분3']=='WORKBOX')]['이용금액(당월)'].sum())
    od_box_2.append(boa2023[i][(boa2023[i]['채널']!='파트너 매출')&(boa2023[i]['구분3']=='WORKBOX')]['매출금액(당월)'].sum())
    pt_box_2.append(boa2023[i][(boa2023[i]['채널']=='파트너 매출')&(boa2023[i]['구분3']=='WORKBOX')]['매출금액(당월)'].sum())
    od_place_1.append(boa2023[i][(boa2023[i]['채널']!='파트너 매출')&(boa2023[i]['구분3']=='WORKPLACE')]['이용금액(당월)'].sum())
    pt_place_1.append(boa2023[i][(boa2023[i]['채널']=='파트너 매출')&(boa2023[i]['구분3']=='WORKPLACE')]['이용금액(당월)'].sum())
    od_place_2.append(boa2023[i][(boa2023[i]['채널']!='파트너 매출')&(boa2023[i]['구분3']=='WORKPLACE')]['매출금액(당월)'].sum())
    pt_place_2.append(boa2023[i][(boa2023[i]['채널']=='파트너 매출')&(boa2023[i]['구분3']=='WORKPLACE')]['매출금액(당월)'].sum())

# %%
sum2023 = pd.DataFrame([od_works_1, pt_works_1, od_box_1, pt_box_1, od_place_1, pt_place_1, od_works_2, pt_works_2, od_box_2, pt_box_2, od_place_2, pt_place_2])

# %%
sum2023.to_excel('/Users/user/Documents/진행중 업무/sum2023.xlsx', index=False)

# %%
od_works_lite_1 = []
od_works_lite_2 = []
od_works_basic_1 = []
od_works_basic_2 = []
od_works_premium_1 = []
od_works_premium_2 = []
od_works_etc_1 = []
od_works_etc_2 = []
od_box_basic_1 = []
od_box_basic_2 = []
od_box_etc_1 = []
od_box_etc_2 = []
od_place_lite_1 = []
od_place_lite_2 = []
od_place_basic_1 = []
od_place_basic_2 = []
od_place_finance_1 = []
od_place_finance_2 = []
od_place_hr_1 = []
od_place_hr_2 = []
od_place_etc_1 = []
od_place_etc_2 = []
pt_works_lite_1 = []
pt_works_lite_2 = []
pt_works_basic_1 = []
pt_works_basic_2 = []
pt_works_premium_1 = []
pt_works_premium_2 = []
pt_works_etc_1 = []
pt_works_etc_2 = []
pt_box_basic_1 = []
pt_box_basic_2 = []
pt_box_etc_1 = []
pt_box_etc_2 = []
pt_place_lite_1 = []
pt_place_lite_2 = []
pt_place_basic_1 = []
pt_place_basic_2 = []
pt_place_finance_1 = []
pt_place_finance_2 = []
pt_place_hr_1 = []
pt_place_hr_2 = []
pt_place_etc_1 = []
pt_place_etc_2 = []
boa2024_1 = [boa13, boa14, boa15, boa16, boa17, boa18]
for i in range(0,len(boa2024_1)) :
    od_works_lite_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS LITE'))]['이용금액(당월)'].sum())
    od_works_lite_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS LITE'))]['매출금액(당월)'].sum())
    od_works_basic_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS BASIC'))]['이용금액(당월)'].sum())
    od_works_basic_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS BASIC'))]['매출금액(당월)'].sum())
    od_works_premium_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS PREMIUM'))]['이용금액(당월)'].sum())
    od_works_premium_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS PREMIUM'))]['매출금액(당월)'].sum())
    od_works_etc_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS VOLUME'))]['이용금액(당월)'].sum())
    od_works_etc_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS VOLUME'))]['매출금액(당월)'].sum())
    od_box_basic_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKBOX')&(boa2024_1[i]['상품명']=='Workbox Basic')]['이용금액(당월)'].sum())
    od_box_basic_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKBOX')&(boa2024_1[i]['상품명']=='Workbox Basic')]['매출금액(당월)'].sum())
    od_box_etc_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKBOX')&(boa2024_1[i]['상품명'].isin(['Workbox Online Editor', 'Workbox 공용용량','부가서비스(전자계약)']))]['이용금액(당월)'].sum())
    od_box_etc_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKBOX')&(boa2024_1[i]['상품명'].isin(['Workbox Online Editor', 'Workbox 공용용량','부가서비스(전자계약)']))]['매출금액(당월)'].sum())
    od_place_lite_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Lite'))]['이용금액(당월)'].sum())
    od_place_lite_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Lite'))]['매출금액(당월)'].sum())
    od_place_basic_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Basic'))]['이용금액(당월)'].sum())
    od_place_basic_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Basic'))]['매출금액(당월)'].sum())
    od_place_finance_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Finance'))]['이용금액(당월)'].sum())
    od_place_finance_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Finance'))]['매출금액(당월)'].sum())
    od_place_hr_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE HR'))]['이용금액(당월)'].sum())
    od_place_hr_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE HR'))]['매출금액(당월)'].sum())
    od_place_etc_1.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE'))&(~boa2024_1[i]['상품명'].isin(['WORKPLACE Lite','WORKPLACE Basic','WORKPLACE Finance','WORKPLACE HR','WORKPLACE Lite (Deprecated)','WORKPLACE Basic (Deprecated)','WORKPLACE Finance (Deprecated)','WORKPLACE HR (Deprecated)']))]['이용금액(당월)'].sum())
    od_place_etc_2.append(boa2024_1[i][(boa2024_1[i]['채널']!='파트너 매출')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE'))&(~boa2024_1[i]['상품명'].isin(['WORKPLACE Lite','WORKPLACE Basic','WORKPLACE Finance','WORKPLACE HR','WORKPLACE Lite (Deprecated)','WORKPLACE Basic (Deprecated)','WORKPLACE Finance (Deprecated)','WORKPLACE HR (Deprecated)']))]['매출금액(당월)'].sum())
    pt_works_lite_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS LITE'))]['이용금액(당월)'].sum())
    pt_works_lite_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS LITE'))]['매출금액(당월)'].sum())
    pt_works_basic_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS BASIC'))]['이용금액(당월)'].sum())
    pt_works_basic_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS BASIC'))]['매출금액(당월)'].sum())
    pt_works_premium_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS PREMIUM'))]['이용금액(당월)'].sum())
    pt_works_premium_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS PREMIUM'))]['매출금액(당월)'].sum())
    pt_works_etc_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS VOLUME'))]['이용금액(당월)'].sum())
    pt_works_etc_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='NAVER WORKS')&(boa2024_1[i]['상품명'].str.startswith('NAVER WORKS VOLUME'))]['매출금액(당월)'].sum())
    pt_box_basic_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKBOX')&(boa2024_1[i]['상품명']=='Workbox Basic')]['이용금액(당월)'].sum())
    pt_box_basic_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKBOX')&(boa2024_1[i]['상품명']=='Workbox Basic')]['매출금액(당월)'].sum())
    pt_box_etc_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKBOX')&(~boa2024_1[i]['상품명'].isin(['Workbox Basic']))]['이용금액(당월)'].sum())
    pt_box_etc_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKBOX')&(~boa2024_1[i]['상품명'].isin(['Workbox Basic']))]['매출금액(당월)'].sum())
    pt_place_lite_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Lite'))]['이용금액(당월)'].sum())
    pt_place_lite_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Lite'))]['매출금액(당월)'].sum())
    pt_place_basic_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Basic'))]['이용금액(당월)'].sum())
    pt_place_basic_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Basic'))]['매출금액(당월)'].sum())
    pt_place_finance_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Finance'))]['이용금액(당월)'].sum())
    pt_place_finance_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE Finance'))]['매출금액(당월)'].sum())
    pt_place_hr_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE HR'))]['이용금액(당월)'].sum())
    pt_place_hr_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['구분3']=='WORKPLACE')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE HR'))]['매출금액(당월)'].sum())
    pt_place_etc_1.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE'))&(~boa2024_1[i]['상품명'].isin(['WORKPLACE Lite','WORKPLACE Basic','WORKPLACE Finance','WORKPLACE HR','WORKPLACE Lite (Deprecated)','WORKPLACE Basic (Deprecated)','WORKPLACE Finance (Deprecated)','WORKPLACE HR (Deprecated)']))]['이용금액(당월)'].sum())
    pt_place_etc_2.append(boa2024_1[i][(boa2024_1[i]['채널']=='파트너 매출')&(boa2024_1[i]['상품명'].str.startswith('WORKPLACE'))&(~boa2024_1[i]['상품명'].isin(['WORKPLACE Lite','WORKPLACE Basic','WORKPLACE Finance','WORKPLACE HR','WORKPLACE Lite (Deprecated)','WORKPLACE Basic (Deprecated)','WORKPLACE Finance (Deprecated)','WORKPLACE HR (Deprecated)']))]['매출금액(당월)'].sum())

# %%
sum2024_1 = pd.DataFrame([od_works_lite_1, pt_works_lite_1, od_works_basic_1, pt_works_basic_1, od_works_premium_1, pt_works_premium_1, od_works_etc_1, pt_works_etc_1,
                          od_box_basic_1, pt_box_basic_1, od_box_etc_1, pt_box_etc_1,
                          od_place_lite_1, pt_place_lite_1, od_place_basic_1, pt_place_basic_1, od_place_finance_1, pt_place_finance_1, od_place_hr_1, pt_place_hr_1, od_place_etc_1, pt_place_etc_1,
                          od_works_lite_2, pt_works_lite_2, od_works_basic_2, pt_works_basic_2, od_works_premium_2, pt_works_premium_2, od_works_etc_2, pt_works_etc_2,
                          od_box_basic_2, pt_box_basic_2, od_box_etc_2, pt_box_etc_2,
                          od_place_lite_2, pt_place_lite_2, od_place_basic_2, pt_place_basic_2, od_place_finance_2, pt_place_finance_2, od_place_hr_2, pt_place_hr_2, od_place_etc_2, pt_place_etc_2])

# %%
sum2024_1.to_excel('/Users/user/Documents/진행중 업무/sum2024_1.xlsx', index=False)

# %%
od_cor_lite_1 = []
od_cor_lite_2 = []
od_cor_standard_1 = []
od_cor_standard_2 = []
od_cor_standard_p_1 = []
od_cor_standard_p_2 = []
od_cor_etc_1 = []
od_cor_etc_2 = []
od_box_basic_1 = []
od_box_basic_2 = []
od_box_etc_1 = []
od_box_etc_2 = []
od_drv_lite_1 = []
od_drv_lite_2 = []
od_drv_standard_1 = []
od_drv_standard_2 = []
od_drv_standard_p_1 = []
od_drv_standard_p_2 = []
od_place_app_1 = []
od_place_app_2 = []
od_place_att_1 = []
od_place_att_2 = []
od_place_fin_1 = []
od_place_fin_2 = []
od_place_pay_1 = []
od_place_pay_2 = []
od_place_etc_1 = []
od_place_etc_2 = []
pt_cor_lite_1 = []
pt_cor_lite_2 = []
pt_cor_standard_1 = []
pt_cor_standard_2 = []
pt_cor_standard_p_1 = []
pt_cor_standard_p_2 = []
pt_cor_etc_1 = []
pt_cor_etc_2 = []
pt_box_basic_1 = []
pt_box_basic_2 = []
pt_box_etc_1 = []
pt_box_etc_2 = []
pt_drv_lite_1 = []
pt_drv_lite_2 = []
pt_drv_standard_1 = []
pt_drv_standard_2 = []
pt_drv_standard_p_1 = []
pt_drv_standard_p_2 = []
pt_place_app_1 = []
pt_place_app_2 = []
pt_place_att_1 = []
pt_place_att_2 = []
pt_place_fin_1 = []
pt_place_fin_2 = []
pt_place_pay_1 = []
pt_place_pay_2 = []
pt_place_etc_1 = []
pt_place_etc_2 = []
boa2024_2 = [boa18, boa19, boa20, boa21, boa22]
for i in range(0,len(boa2024_2)) :
    od_cor_lite_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Lite')]['이용금액(당월)'].sum())
    od_cor_lite_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Lite')]['매출금액(당월)'].sum())
    od_cor_standard_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Standard')]['이용금액(당월)'].sum())
    od_cor_standard_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Standard')]['매출금액(당월)'].sum())
    od_cor_standard_p_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Standard Plus')]['이용금액(당월)'].sum())
    od_cor_standard_p_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Standard Plus')]['매출금액(당월)'].sum())
    od_cor_etc_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(~boa2024_2[i]['상품명'].str.startswith('NAVER WORKS'))&(~boa2024_2[i]['상품명'].isin(['웍스 코어 Lite','웍스 코어 Standard','웍스 코어 Standard Plus']))]['이용금액(당월)'].sum())
    od_cor_etc_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(~boa2024_2[i]['상품명'].str.startswith('NAVER WORKS'))&(~boa2024_2[i]['상품명'].isin(['웍스 코어 Lite','웍스 코어 Standard','웍스 코어 Standard Plus']))]['매출금액(당월)'].sum())
    od_box_basic_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='Workbox Basic')]['이용금액(당월)'].sum())
    od_box_basic_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='Workbox Basic')]['매출금액(당월)'].sum())
    od_box_etc_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명'].isin(['Workbox Online Editor', 'Workbox 공용용량','부가서비스(전자계약)']))]['이용금액(당월)'].sum())
    od_box_etc_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명'].isin(['Workbox Online Editor', 'Workbox 공용용량','부가서비스(전자계약)']))]['매출금액(당월)'].sum())
    od_drv_lite_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Lite')]['이용금액(당월)'].sum())
    od_drv_lite_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Lite')]['매출금액(당월)'].sum())
    od_drv_standard_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Standard')]['이용금액(당월)'].sum())
    od_drv_standard_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Standard')]['매출금액(당월)'].sum())
    od_drv_standard_p_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Standard Plus')]['이용금액(당월)'].sum())
    od_drv_standard_p_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Standard Plus')]['매출금액(당월)'].sum())
    od_place_app_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 결재')]['이용금액(당월)'].sum())
    od_place_app_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 결재')]['매출금액(당월)'].sum())
    od_place_att_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 근태')]['이용금액(당월)'].sum())
    od_place_att_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 근태')]['매출금액(당월)'].sum())
    od_place_fin_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 재무')]['이용금액(당월)'].sum())
    od_place_fin_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 재무')]['매출금액(당월)'].sum())
    od_place_pay_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 급여')]['이용금액(당월)'].sum())
    od_place_pay_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 급여')]['매출금액(당월)'].sum())
    od_place_etc_1.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명'].str.startswith('웍스'))&(~boa2024_2[i]['상품명'].isin(['웍스 결재','웍스 근태','웍스 재무','웍스 급여']))]['이용금액(당월)'].sum())
    od_place_etc_2.append(boa2024_2[i][(boa2024_2[i]['채널']!='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명'].str.startswith('웍스'))&(~boa2024_2[i]['상품명'].isin(['웍스 결재','웍스 근태','웍스 재무','웍스 급여']))]['매출금액(당월)'].sum())
    pt_cor_lite_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Lite')]['이용금액(당월)'].sum())
    pt_cor_lite_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Lite')]['매출금액(당월)'].sum())
    pt_cor_standard_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Standard')]['이용금액(당월)'].sum())
    pt_cor_standard_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Standard')]['매출금액(당월)'].sum())
    pt_cor_standard_p_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Standard Plus')]['이용금액(당월)'].sum())
    pt_cor_standard_p_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(boa2024_2[i]['상품명']=='웍스 코어 Standard Plus')]['매출금액(당월)'].sum())
    pt_cor_etc_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(~boa2024_2[i]['상품명'].str.startswith('NAVER WORKS'))&(~boa2024_2[i]['상품명'].isin(['웍스 코어 Lite','웍스 코어 Standard','웍스 코어 Standard Plus']))]['이용금액(당월)'].sum())
    pt_cor_etc_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='NAVER WORKS')&(~boa2024_2[i]['상품명'].str.startswith('NAVER WORKS'))&(~boa2024_2[i]['상품명'].isin(['웍스 코어 Lite','웍스 코어 Standard','웍스 코어 Standard Plus']))]['매출금액(당월)'].sum())
    pt_box_basic_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='Workbox Basic')]['이용금액(당월)'].sum())
    pt_box_basic_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='Workbox Basic')]['매출금액(당월)'].sum())
    pt_box_etc_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(~boa2024_2[i]['상품명'].isin(['Workbox Basic']))]['이용금액(당월)'].sum())
    pt_box_etc_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(~boa2024_2[i]['상품명'].isin(['Workbox Basic']))]['매출금액(당월)'].sum())
    pt_drv_lite_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Lite')]['이용금액(당월)'].sum())
    pt_drv_lite_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Lite')]['매출금액(당월)'].sum())
    pt_drv_standard_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Standard')]['이용금액(당월)'].sum())
    pt_drv_standard_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Standard')]['매출금액(당월)'].sum())
    pt_drv_standard_p_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Standard Plus')]['이용금액(당월)'].sum())
    pt_drv_standard_p_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKBOX')&(boa2024_2[i]['상품명']=='웍스 드라이브 Standard Plus')]['매출금액(당월)'].sum())
    pt_place_app_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 결재')]['이용금액(당월)'].sum())
    pt_place_app_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 결재')]['매출금액(당월)'].sum())
    pt_place_att_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 근태')]['이용금액(당월)'].sum())
    pt_place_att_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 근태')]['매출금액(당월)'].sum())
    pt_place_fin_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 재무')]['이용금액(당월)'].sum())
    pt_place_fin_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 재무')]['매출금액(당월)'].sum())
    pt_place_pay_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 급여')]['이용금액(당월)'].sum())
    pt_place_pay_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명']=='웍스 급여')]['매출금액(당월)'].sum())
    pt_place_etc_1.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명'].str.startswith('웍스'))&(~boa2024_2[i]['상품명'].isin(['웍스 결재','웍스 근태','웍스 재무','웍스 급여']))]['이용금액(당월)'].sum())
    pt_place_etc_2.append(boa2024_2[i][(boa2024_2[i]['채널']=='파트너 매출')&(boa2024_2[i]['구분3']=='WORKPLACE')&(boa2024_2[i]['상품명'].str.startswith('웍스'))&(~boa2024_2[i]['상품명'].isin(['웍스 결재','웍스 근태','웍스 재무','웍스 급여']))]['매출금액(당월)'].sum())

# %%
sum2024_2 = pd.DataFrame([od_cor_lite_1, pt_cor_lite_1, od_cor_standard_1, pt_cor_standard_1, od_cor_standard_p_1, pt_cor_standard_p_1, od_cor_etc_1, pt_cor_etc_1,
                          od_box_basic_1, pt_box_basic_1, od_box_etc_1, pt_box_etc_1,
                          od_drv_lite_1, pt_drv_lite_1, od_drv_standard_1, pt_drv_standard_1, od_drv_standard_p_1, pt_drv_standard_p_1,
                          od_place_app_1, pt_place_app_1, od_place_att_1, pt_place_att_1, od_place_fin_1, pt_place_fin_1, od_place_pay_1, pt_place_pay_1, od_place_etc_1, pt_place_etc_1,
                          od_cor_lite_2, pt_cor_lite_2, od_cor_standard_2, pt_cor_standard_2, od_cor_standard_p_2, pt_cor_standard_p_2, od_cor_etc_2, pt_cor_etc_2,
                          od_box_basic_2, pt_box_basic_2, od_box_etc_2, pt_box_etc_2,
                          od_drv_lite_2, pt_drv_lite_2, od_drv_standard_2, pt_drv_standard_2, od_drv_standard_p_2, pt_drv_standard_p_2,
                          od_place_app_2, pt_place_app_2, od_place_att_2, pt_place_att_2, od_place_fin_2, pt_place_fin_2, od_place_pay_2, pt_place_pay_2, od_place_etc_2, pt_place_etc_2])

# %%
sum2024_2.to_excel('/Users/user/Documents/진행중 업무/sum2024_2.xlsx', index=False)
