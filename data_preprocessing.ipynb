# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.rcParams['font.family'] = 'AppleGothic'

# %%
boa1 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202201)new.xlsx')
boa2 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202202)new.xlsx')
boa3 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202203)new.xlsx')
boa4 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202204)new.xlsx')
boa5 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202205)new.xlsx')
boa6 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202206)new.xlsx')
boa7 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202207)new.xlsx')
boa8 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202208)new.xlsx')
boa9 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202209)new.xlsx')
boa10 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202210)new.xlsx')
boa11 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202211)new.xlsx')
boa12 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202212)new.xlsx')
boa13 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202301)new.xlsx')
boa14 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202302)new.xlsx')
boa15 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202303)new.xlsx')
boa16 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202304)new.xlsx')
boa17 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202305)new.xlsx')
boa18 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202306)new.xlsx')
boa19 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202307)new.xlsx')
boa20 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202308)new.xlsx')
boa21 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202309)new.xlsx')
boa22 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202310)new.xlsx')
boa23 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202311)new.xlsx')
boa24 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202312)new.xlsx')
boa25 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202401)new.xlsx')
boa26 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202402)new.xlsx')
boa27 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202403)new.xlsx')
boa28 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202404)new.xlsx')
boa29 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202405)new.xlsx')
boa30 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202406)new.xlsx')
boa31 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202407)new.xlsx')
boa32 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202408)new.xlsx')
boa33 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202409)new.xlsx')
boa34 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202410)new.xlsx')
boa35 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/BOA(202411)new.xlsx')
boa36 = pd.read_excel('/Users/user/Documents/진행중 업무/데이터/BOA/202412 BOA (New).xlsx')

# %%
boa1['NCP회원번호'] = pd.to_numeric(boa1['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa2['NCP회원번호'] = pd.to_numeric(boa2['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa3['NCP회원번호'] = pd.to_numeric(boa3['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa4['NCP회원번호'] = pd.to_numeric(boa4['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa5['NCP회원번호'] = pd.to_numeric(boa5['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa6['NCP회원번호'] = pd.to_numeric(boa6['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa7['NCP회원번호'] = pd.to_numeric(boa7['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa8['NCP회원번호'] = pd.to_numeric(boa8['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa9['NCP회원번호'] = pd.to_numeric(boa9['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa10['NCP회원번호'] = pd.to_numeric(boa10['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa11['NCP회원번호'] = pd.to_numeric(boa11['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa12['NCP회원번호'] = pd.to_numeric(boa12['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa13['NCP회원번호'] = pd.to_numeric(boa13['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa14['NCP회원번호'] = pd.to_numeric(boa14['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa15['NCP회원번호'] = pd.to_numeric(boa15['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa16['NCP회원번호'] = pd.to_numeric(boa16['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa17['NCP회원번호'] = pd.to_numeric(boa17['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa18['NCP회원번호'] = pd.to_numeric(boa18['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa19['NCP회원번호'] = pd.to_numeric(boa19['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa20['NCP회원번호'] = pd.to_numeric(boa20['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa21['NCP회원번호'] = pd.to_numeric(boa21['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa22['NCP회원번호'] = pd.to_numeric(boa22['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa23['NCP회원번호'] = pd.to_numeric(boa23['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa24['NCP회원번호'] = pd.to_numeric(boa24['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa25['NCP회원번호'] = pd.to_numeric(boa25['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa26['NCP회원번호'] = pd.to_numeric(boa26['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa27['NCP회원번호'] = pd.to_numeric(boa27['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa28['NCP회원번호'] = pd.to_numeric(boa28['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa29['NCP회원번호'] = pd.to_numeric(boa29['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa30['NCP회원번호'] = pd.to_numeric(boa30['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa31['NCP회원번호'] = pd.to_numeric(boa31['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa32['NCP회원번호'] = pd.to_numeric(boa32['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa33['NCP회원번호'] = pd.to_numeric(boa33['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa34['NCP회원번호'] = pd.to_numeric(boa34['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa35['NCP회원번호'] = pd.to_numeric(boa35['NCP회원번호'], errors='coerce').fillna(0).astype(int)
boa36['NCP회원번호'] = pd.to_numeric(boa36['NCP회원번호'], errors='coerce').fillna(0).astype(int)

# %%
paydb_base0 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2021년 12월 31일 base.csv')
paydb_base_2022 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2022년 월간 base (마지막 주 수요일 기준).csv')
paydb_base_2023 = pd.read_csv('/Users/user/Documents/진행중 업무/2023년 주간 base.csv')
paydb_base_2024 = pd.read_csv('/Users/user/Documents/진행중 업무/2024년 base(~2024.6.3) 주간.csv')
paydb_base30 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2024년 6월 base(6:4~).csv')
paydb_base31 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2024년 7월 base.csv')
paydb_base32 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2024년 8월 base.csv')
paydb_base33 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2024년 9월 base.csv')
paydb_base34 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2024년 10월 base.csv')
paydb_base35 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2024년 11월 base.csv')
paydb_base36_1 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2024년 12월(~12:28) base.csv')
paydb_base36_2 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/pay 2024.12.29~31 (base).csv')

paydb_option0 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2021년 12월 31일 option.csv')
paydb_option_2022 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2022년 월간 option (마지막 주 수요일 기준).csv')
paydb_option_2023 = pd.read_csv('/Users/user/Documents/진행중 업무/2023년 option(주간).csv')
paydb_option_2024 = pd.read_csv('/Users/user/Documents/진행중 업무/2024년 option 주간(~2024.6.3).csv')
paydb_option30 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2024년 6월 option(6:4~).csv')
paydb_option31 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2024년 7월 option.csv')
paydb_option32 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2024년 8월 option.csv')
paydb_option33 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2024년 9월 option.csv')
paydb_option34 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2024년 10월 option.csv')
paydb_option35 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2024년 11월 option.csv')
paydb_option36_1 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2024년 12월 option (~12:28).csv')
paydb_option36_2 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/pay 2024.12.29~31 (option).csv')

# %%
ncd_box13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2301.xlsx')
ncd_box14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2302.xlsx')
ncd_box15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2303.xlsx')
ncd_box16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2304.xlsx')
ncd_box17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2305.xlsx')
ncd_box18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2306.xlsx')
ncd_box19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2307.xlsx')
ncd_box20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2308.xlsx')
ncd_box21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2309.xlsx')
ncd_box22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2310.xlsx')
ncd_box23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2311.xlsx')
ncd_box24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2312.xlsx')
ncd_box25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2401.xlsx')
ncd_box26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2402.xlsx')
ncd_box27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2403.xlsx')
ncd_box28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2404.xlsx')
ncd_box29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2405.xlsx')
ncd_box30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2406.xlsx')
ncd_box31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2407.xlsx')
ncd_box32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2408.xlsx')
ncd_box33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2409.xlsx')
ncd_box34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2410.xlsx')
ncd_box35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_box2411.xlsx')

# %%
ncd_lt13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2301.xlsx')
ncd_lt14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2302.xlsx')
ncd_lt15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2303.xlsx')
ncd_lt16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2304.xlsx')
ncd_lt17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2305.xlsx')
ncd_lt18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2306.xlsx')
ncd_lt19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2307.xlsx')
ncd_lt20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2308.xlsx')
ncd_lt21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2309.xlsx')
ncd_lt22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2310.xlsx')
ncd_lt23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2311.xlsx')
ncd_lt24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2312.xlsx')
ncd_lt25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2401.xlsx')
ncd_lt26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2402.xlsx')
ncd_lt27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2403.xlsx')
ncd_lt28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2404.xlsx')
ncd_lt29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2405.xlsx')
ncd_lt30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_workslt2406.xlsx')
ncd_corlt30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corlt2406.xlsx')
ncd_corlt31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corlt2407.xlsx')
ncd_corlt32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corlt2408.xlsx')
ncd_corlt33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corlt2409.xlsx')
ncd_corlt34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corlt2410.xlsx')
ncd_corlt35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corlt2411.xlsx')
ncd_corlt36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corlt2412.xlsx')
ncd_corlt37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corlt2501.xlsx')

# %%
ncd_bs13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2301.xlsx')
ncd_bs14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2302.xlsx')
ncd_bs15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2303.xlsx')
ncd_bs16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2304.xlsx')
ncd_bs17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2305.xlsx')
ncd_bs18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2306.xlsx')
ncd_bs19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2307.xlsx')
ncd_bs20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2308.xlsx')
ncd_bs21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2309.xlsx')
ncd_bs22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2310.xlsx')
ncd_bs23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2311.xlsx')
ncd_bs24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2312.xlsx')
ncd_bs25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2401.xlsx')
ncd_bs26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2402.xlsx')
ncd_bs27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2403.xlsx')
ncd_bs28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2404.xlsx')
ncd_bs29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2405.xlsx')
ncd_bs30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbs2406.xlsx')
ncd_corstd30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstd2406.xlsx')
ncd_corstd31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstd2407.xlsx')
ncd_corstd32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstd2408.xlsx')
ncd_corstd33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstd2409.xlsx')
ncd_corstd34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstd2410.xlsx')
ncd_corstd35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstd2411.xlsx')
ncd_corstd36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstd2412.xlsx')
ncd_corstd37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstd2501.xlsx')

# %%
ncd_prm13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2301.xlsx')
ncd_prm14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2302.xlsx')
ncd_prm15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2303.xlsx')
ncd_prm16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2304.xlsx')
ncd_prm17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2305.xlsx')
ncd_prm18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2306.xlsx')
ncd_prm19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2307.xlsx')
ncd_prm20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2308.xlsx')
ncd_prm21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2309.xlsx')
ncd_prm22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2310.xlsx')
ncd_prm23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2311.xlsx')
ncd_prm24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2312.xlsx')
ncd_prm25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2401.xlsx')
ncd_prm26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2402.xlsx')
ncd_prm27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2403.xlsx')
ncd_prm28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2404.xlsx')
ncd_prm29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2405.xlsx')
ncd_prm30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprm2406.xlsx')
ncd_corstdp30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstdp2406.xlsx')
ncd_corstdp31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstdp2407.xlsx')
ncd_corstdp32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstdp2408.xlsx')
ncd_corstdp33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstdp2409.xlsx')
ncd_corstdp34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstdp2410.xlsx')
ncd_corstdp35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstdp2411.xlsx')
ncd_corstdp36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstdp2412.xlsx')
ncd_corstdp37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_corstdp2501.xlsx')

# %%
ncd_ltt13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2301.xlsx')
ncd_ltt14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2302.xlsx')
ncd_ltt15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2303.xlsx')
ncd_ltt16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2304.xlsx')
ncd_ltt17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2305.xlsx')
ncd_ltt18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2306.xlsx')
ncd_ltt19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2307.xlsx')
ncd_ltt20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2308.xlsx')
ncd_ltt21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2309.xlsx')
ncd_ltt22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2310.xlsx')
ncd_ltt23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2311.xlsx')
ncd_ltt24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2312.xlsx')
ncd_ltt25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2401.xlsx')
ncd_ltt26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2402.xlsx')
ncd_ltt27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2403.xlsx')
ncd_ltt28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2404.xlsx')
ncd_ltt29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2405.xlsx')
ncd_ltt30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksltt2406.xlsx')

ncd_bst13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2301.xlsx')
ncd_bst14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2302.xlsx')
ncd_bst15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2303.xlsx')
ncd_bst16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2304.xlsx')
ncd_bst17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2305.xlsx')
ncd_bst18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2306.xlsx')
ncd_bst19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2307.xlsx')
ncd_bst20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2308.xlsx')
ncd_bst21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2309.xlsx')
ncd_bst22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2310.xlsx')
ncd_bst23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2311.xlsx')
ncd_bst24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2312.xlsx')
ncd_bst25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2401.xlsx')
ncd_bst26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2402.xlsx')
ncd_bst27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2403.xlsx')
ncd_bst28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2404.xlsx')
ncd_bst29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2405.xlsx')
ncd_bst30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksbst2406.xlsx')

ncd_prmt13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2301.xlsx')
ncd_prmt14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2302.xlsx')
ncd_prmt15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2303.xlsx')
ncd_prmt16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2304.xlsx')
ncd_prmt17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2305.xlsx')
ncd_prmt18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2306.xlsx')
ncd_prmt19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2307.xlsx')
ncd_prmt20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2308.xlsx')
ncd_prmt21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2309.xlsx')
ncd_prmt22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2310.xlsx')
ncd_prmt23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2311.xlsx')
ncd_prmt24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2312.xlsx')
ncd_prmt25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2401.xlsx')
ncd_prmt26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2402.xlsx')
ncd_prmt27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2403.xlsx')
ncd_prmt28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2404.xlsx')
ncd_prmt29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2405.xlsx')
ncd_prmt30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_worksprmt2406.xlsx')

# %%
ncd_cort30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cort2406.xlsx')
ncd_cort31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cort2407.xlsx')
ncd_cort32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cort2408.xlsx')
ncd_cort33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cort2409.xlsx')
ncd_cort34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cort2410.xlsx')
ncd_cort35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cort2411.xlsx')
ncd_cort36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cort2412.xlsx')
ncd_cort37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cort2501.xlsx')

# %%
ncd_drv28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2404.xlsx')
ncd_drv29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2405.xlsx')
ncd_drv30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2406.xlsx')
ncd_drv31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2407.xlsx')
ncd_drv32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2408.xlsx')
ncd_drv33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2409.xlsx')
ncd_drv34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2410.xlsx')
ncd_drv35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2411.xlsx')
ncd_drv36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2412.xlsx')
ncd_drv37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_drv2501.xlsx')

# %%
ncd_cnt34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cnt2410.xlsx')
ncd_cnt35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cnt2411.xlsx')
ncd_cnt36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cnt2412.xlsx')
ncd_cnt37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_cnt2501.xlsx')

# %%
ncd_placeltt13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2301.xlsx')
ncd_placeltt14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2302.xlsx')
ncd_placeltt15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2303.xlsx')
ncd_placeltt16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2304.xlsx')
ncd_placeltt17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2305.xlsx')
ncd_placeltt18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2306.xlsx')
ncd_placeltt19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2307.xlsx')
ncd_placeltt20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2308.xlsx')
ncd_placeltt21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2309.xlsx')
ncd_placeltt22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2310.xlsx')
ncd_placeltt23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2311.xlsx')
ncd_placeltt24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2312.xlsx')
ncd_placeltt25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2401.xlsx')
ncd_placeltt26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2402.xlsx')
ncd_placeltt27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2403.xlsx')
ncd_placeltt28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2404.xlsx')
ncd_placeltt29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2405.xlsx')
ncd_placeltt30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placeltt2406.xlsx')

ncd_placelt13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2301.xlsx')
ncd_placelt14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2302.xlsx')
ncd_placelt15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2303.xlsx')
ncd_placelt16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2304.xlsx')
ncd_placelt17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2305.xlsx')
ncd_placelt18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2306.xlsx')
ncd_placelt19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2307.xlsx')
ncd_placelt20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2308.xlsx')
ncd_placelt21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2309.xlsx')
ncd_placelt22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2310.xlsx')
ncd_placelt23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2311.xlsx')
ncd_placelt24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2312.xlsx')
ncd_placelt25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2401.xlsx')
ncd_placelt26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2402.xlsx')
ncd_placelt27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2403.xlsx')
ncd_placelt28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2404.xlsx')
ncd_placelt29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2405.xlsx')
ncd_placelt30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placelt2406.xlsx')

ncd_placebst13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2301.xlsx')
ncd_placebst14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2302.xlsx')
ncd_placebst15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2303.xlsx')
ncd_placebst16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2304.xlsx')
ncd_placebst17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2305.xlsx')
ncd_placebst18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2306.xlsx')
ncd_placebst19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2307.xlsx')
ncd_placebst20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2308.xlsx')
ncd_placebst21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2309.xlsx')
ncd_placebst22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2310.xlsx')
ncd_placebst23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2311.xlsx')
ncd_placebst24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2312.xlsx')
ncd_placebst25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2401.xlsx')
ncd_placebst26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2402.xlsx')
ncd_placebst27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2403.xlsx')
ncd_placebst28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2404.xlsx')
ncd_placebst29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2405.xlsx')
ncd_placebst30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebst2406.xlsx')

ncd_placebs13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2301.xlsx')
ncd_placebs14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2302.xlsx')
ncd_placebs15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2303.xlsx')
ncd_placebs16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2304.xlsx')
ncd_placebs17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2305.xlsx')
ncd_placebs18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2306.xlsx')
ncd_placebs19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2307.xlsx')
ncd_placebs20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2308.xlsx')
ncd_placebs21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2309.xlsx')
ncd_placebs22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2310.xlsx')
ncd_placebs23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2311.xlsx')
ncd_placebs24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2312.xlsx')
ncd_placebs25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2401.xlsx')
ncd_placebs26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2402.xlsx')
ncd_placebs27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2403.xlsx')
ncd_placebs28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2404.xlsx')
ncd_placebs29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2405.xlsx')
ncd_placebs30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placebs2406.xlsx')

ncd_placehr13 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2301.xlsx')
ncd_placehr14 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2302.xlsx')
ncd_placehr15 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2303.xlsx')
ncd_placehr16 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2304.xlsx')
ncd_placehr17 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2305.xlsx')
ncd_placehr18 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2306.xlsx')
ncd_placehr19 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2307.xlsx')
ncd_placehr20 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2308.xlsx')
ncd_placehr21 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2309.xlsx')
ncd_placehr22 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2310.xlsx')
ncd_placehr23 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2311.xlsx')
ncd_placehr24 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2312.xlsx')
ncd_placehr25 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2401.xlsx')
ncd_placehr26 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2402.xlsx')
ncd_placehr27 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2403.xlsx')
ncd_placehr28 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2404.xlsx')
ncd_placehr29 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2405.xlsx')
ncd_placehr30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_placehr2406.xlsx')

# %%
ncd_app30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_app2406.xlsx')
ncd_app31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_app2407.xlsx')
ncd_app32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_app2408.xlsx')
ncd_app33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_app2409.xlsx')
ncd_app34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_app2410.xlsx')
ncd_app35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_app2411.xlsx')
ncd_app36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_app2412.xlsx')
ncd_app37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_app2501.xlsx')

ncd_att30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_att2406.xlsx')
ncd_att31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_att2407.xlsx')
ncd_att32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_att2408.xlsx')
ncd_att33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_att2409.xlsx')
ncd_att34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_att2410.xlsx')
ncd_att35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_att2411.xlsx')
ncd_att36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_att2412.xlsx')
ncd_att37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_att2501.xlsx')

ncd_fin30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_fin2406.xlsx')
ncd_fin31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_fin2407.xlsx')
ncd_fin32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_fin2408.xlsx')
ncd_fin33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_fin2409.xlsx')
ncd_fin34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_fin2410.xlsx')
ncd_fin35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_fin2411.xlsx')
ncd_fin36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_fin2412.xlsx')
ncd_fin37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_fin2501.xlsx')

ncd_pay30 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_pay2406.xlsx')
ncd_pay31 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_pay2407.xlsx')
ncd_pay32 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_pay2408.xlsx')
ncd_pay33 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_pay2409.xlsx')
ncd_pay34 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_pay2410.xlsx')
ncd_pay35 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_pay2411.xlsx')
ncd_pay36 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_pay2412.xlsx')
ncd_pay37 = pd.read_excel('/Users/user/Documents/NCD 데이터/ncd_pay2501.xlsx')

# %%
boa1['calc_ymd'] = '2022-01-26'
boa2['calc_ymd'] = '2022-02-23'
boa3['calc_ymd'] = '2022-03-30'
boa4['calc_ymd'] = '2022-04-27'
boa5['calc_ymd'] = '2022-05-25'
boa6['calc_ymd'] = '2022-06-29'
boa7['calc_ymd'] = '2022-07-27'
boa8['calc_ymd'] = '2022-08-31'
boa9['calc_ymd'] = '2022-09-28'
boa10['calc_ymd'] = '2022-10-26'
boa11['calc_ymd'] = '2022-11-30'
boa12['calc_ymd'] = '2022-12-28'

# %%
boa1 = boa1[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa2 = boa2[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa3 = boa3[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa4 = boa4[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa5 = boa5[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa6 = boa6[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa7 = boa7[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa8 = boa8[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa9 = boa9[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa10 = boa10[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa11 = boa11[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]
boa12 = boa12[['NCP회원번호','calc_ymd','상품구분','상품명','단위사용량','채널','파트너회원번호']]

# %%
boa1['testdomainYn'] = 'N'
boa2['testdomainYn'] = 'N'
boa3['testdomainYn'] = 'N'
boa4['testdomainYn'] = 'N'
boa5['testdomainYn'] = 'N'
boa6['testdomainYn'] = 'N'
boa7['testdomainYn'] = 'N'
boa8['testdomainYn'] = 'N'
boa9['testdomainYn'] = 'N'
boa10['testdomainYn'] = 'N'
boa11['testdomainYn'] = 'N'
boa12['testdomainYn'] = 'N'

# %%
ncd_appt30 = ncd_app30[ncd_app30['요금'] == 0]
ncd_app30 = ncd_app30[ncd_app30['요금'] > 0]
ncd_attt30 = ncd_att30[ncd_att30['요금'] == 0]
ncd_att30 = ncd_att30[ncd_att30['요금'] > 0]
ncd_fint30 = ncd_fin30[ncd_fin30['요금'] == 0]
ncd_fin30 = ncd_fin30[ncd_fin30['요금'] > 0]
ncd_payt30 = ncd_pay30[ncd_pay30['요금'] == 0]
ncd_pay30 = ncd_pay30[ncd_pay30['요금'] > 0]

ncd_appt31 = ncd_app31[ncd_app31['요금'] == 0]
ncd_app31 = ncd_app31[ncd_app31['요금'] > 0]
ncd_attt31 = ncd_att31[ncd_att31['요금'] == 0]
ncd_att31 = ncd_att31[ncd_att31['요금'] > 0]
ncd_fint31 = ncd_fin31[ncd_fin31['요금'] == 0]
ncd_fin31 = ncd_fin31[ncd_fin31['요금'] > 0]
ncd_payt31 = ncd_pay31[ncd_pay31['요금'] == 0]
ncd_pay31 = ncd_pay31[ncd_pay31['요금'] > 0]

ncd_appt32 = ncd_app32[ncd_app32['요금'] == 0]
ncd_app32 = ncd_app32[ncd_app32['요금'] > 0]
ncd_attt32 = ncd_att32[ncd_att32['요금'] == 0]
ncd_att32 = ncd_att32[ncd_att32['요금'] > 0]
ncd_fint32 = ncd_fin32[ncd_fin32['요금'] == 0]
ncd_fin32 = ncd_fin32[ncd_fin32['요금'] > 0]
ncd_payt32 = ncd_pay32[ncd_pay32['요금'] == 0]
ncd_pay32 = ncd_pay32[ncd_pay32['요금'] > 0]

ncd_appt33 = ncd_app33[ncd_app33['요금'] == 0]
ncd_app33 = ncd_app33[ncd_app33['요금'] > 0]
ncd_attt33 = ncd_att33[ncd_att33['요금'] == 0]
ncd_att33 = ncd_att33[ncd_att33['요금'] > 0]
ncd_fint33 = ncd_fin33[ncd_fin33['요금'] == 0]
ncd_fin33 = ncd_fin33[ncd_fin33['요금'] > 0]
ncd_payt33 = ncd_pay33[ncd_pay33['요금'] == 0]
ncd_pay33 = ncd_pay33[ncd_pay33['요금'] > 0]

ncd_appt34 = ncd_app34[ncd_app34['요금'] == 0]
ncd_app34 = ncd_app34[ncd_app34['요금'] > 0]
ncd_attt34 = ncd_att34[ncd_att34['요금'] == 0]
ncd_att34 = ncd_att34[ncd_att34['요금'] > 0]
ncd_fint34 = ncd_fin34[ncd_fin34['요금'] == 0]
ncd_fin34 = ncd_fin34[ncd_fin34['요금'] > 0]
ncd_payt34 = ncd_pay34[ncd_pay34['요금'] == 0]
ncd_pay34 = ncd_pay34[ncd_pay34['요금'] > 0]

ncd_appt35 = ncd_app35[ncd_app35['요금'] == 0]
ncd_app35 = ncd_app35[ncd_app35['요금'] > 0]
ncd_attt35 = ncd_att35[ncd_att35['요금'] == 0]
ncd_att35 = ncd_att35[ncd_att35['요금'] > 0]
ncd_fint35 = ncd_fin35[ncd_fin35['요금'] == 0]
ncd_fin35 = ncd_fin35[ncd_fin35['요금'] > 0]
ncd_payt35 = ncd_pay35[ncd_pay35['요금'] == 0]
ncd_pay35 = ncd_pay35[ncd_pay35['요금'] > 0]

ncd_appt36 = ncd_app36[ncd_app36['요금'] == 0]
ncd_app36 = ncd_app36[ncd_app36['요금'] > 0]
ncd_attt36 = ncd_att36[ncd_att36['요금'] == 0]
ncd_att36 = ncd_att36[ncd_att36['요금'] > 0]
ncd_fint36 = ncd_fin36[ncd_fin36['요금'] == 0]
ncd_fin36 = ncd_fin36[ncd_fin36['요금'] > 0]
ncd_payt36 = ncd_pay36[ncd_pay36['요금'] == 0]
ncd_pay36 = ncd_pay36[ncd_pay36['요금'] > 0]

ncd_appt37 = ncd_app37[ncd_app37['요금'] == 0]
ncd_app37 = ncd_app37[ncd_app37['요금'] > 0]
ncd_attt37 = ncd_att37[ncd_att37['요금'] == 0]
ncd_att37 = ncd_att37[ncd_att37['요금'] > 0]
ncd_fint37 = ncd_fin37[ncd_fin37['요금'] == 0]
ncd_fin37 = ncd_fin37[ncd_fin37['요금'] > 0]
ncd_payt37 = ncd_pay37[ncd_pay37['요금'] == 0]
ncd_pay37 = ncd_pay37[ncd_pay37['요금'] > 0]

# %%
ncd_box13['base_item_id'] = ncd_box13['미터링유형코드명']
ncd_box14['base_item_id'] = ncd_box14['미터링유형코드명']
ncd_box15['base_item_id'] = ncd_box15['미터링유형코드명']
ncd_box16['base_item_id'] = ncd_box16['미터링유형코드명']
ncd_box17['base_item_id'] = ncd_box17['미터링유형코드명']
ncd_box18['base_item_id'] = ncd_box18['미터링유형코드명']
ncd_box19['base_item_id'] = ncd_box19['미터링유형코드명']
ncd_box20['base_item_id'] = ncd_box20['미터링유형코드명']
ncd_box21['base_item_id'] = ncd_box21['미터링유형코드명']
ncd_box22['base_item_id'] = ncd_box22['미터링유형코드명']
ncd_box23['base_item_id'] = ncd_box23['미터링유형코드명']
ncd_box24['base_item_id'] = ncd_box24['미터링유형코드명']
ncd_box25['base_item_id'] = ncd_box25['미터링유형코드명']
ncd_box26['base_item_id'] = ncd_box26['미터링유형코드명']
ncd_box27['base_item_id'] = ncd_box27['미터링유형코드명']
ncd_box28['base_item_id'] = ncd_box28['미터링유형코드명']
ncd_box29['base_item_id'] = ncd_box29['미터링유형코드명']
ncd_box30['base_item_id'] = ncd_box30['미터링유형코드명']
ncd_box31['base_item_id'] = ncd_box31['미터링유형코드명']
ncd_box32['base_item_id'] = ncd_box32['미터링유형코드명']
ncd_box33['base_item_id'] = ncd_box33['미터링유형코드명']
ncd_box34['base_item_id'] = ncd_box34['미터링유형코드명']
ncd_box35['base_item_id'] = ncd_box35['미터링유형코드명']

ncd_lt13['base_item_id'] ='LT'
ncd_lt14['base_item_id'] ='LT'
ncd_lt15['base_item_id'] ='LT'
ncd_lt16['base_item_id'] ='LT'
ncd_lt17['base_item_id'] ='LT'
ncd_lt18['base_item_id'] ='LT'
ncd_lt19['base_item_id'] ='LT'
ncd_lt20['base_item_id'] ='LT'
ncd_lt21['base_item_id'] ='LT'
ncd_lt22['base_item_id'] ='LT'
ncd_lt23['base_item_id'] ='LT'
ncd_lt24['base_item_id'] ='LT'
ncd_lt25['base_item_id'] ='LT'
ncd_lt26['base_item_id'] ='LT'
ncd_lt27['base_item_id'] ='LT'
ncd_lt28['base_item_id'] ='LT'
ncd_lt29['base_item_id'] ='LT'
ncd_lt30['base_item_id'] ='LT'

ncd_bs13['base_item_id'] ='BS'
ncd_bs14['base_item_id'] ='BS'
ncd_bs15['base_item_id'] ='BS'
ncd_bs16['base_item_id'] ='BS'
ncd_bs17['base_item_id'] ='BS'
ncd_bs18['base_item_id'] ='BS'
ncd_bs19['base_item_id'] ='BS'
ncd_bs20['base_item_id'] ='BS'
ncd_bs21['base_item_id'] ='BS'
ncd_bs22['base_item_id'] ='BS'
ncd_bs23['base_item_id'] ='BS'
ncd_bs24['base_item_id'] ='BS'
ncd_bs25['base_item_id'] ='BS'
ncd_bs26['base_item_id'] ='BS'
ncd_bs27['base_item_id'] ='BS'
ncd_bs28['base_item_id'] ='BS'
ncd_bs29['base_item_id'] ='BS'
ncd_bs30['base_item_id'] ='BS'

ncd_prm13['base_item_id'] ='PRM'
ncd_prm14['base_item_id'] ='PRM'
ncd_prm15['base_item_id'] ='PRM'
ncd_prm16['base_item_id'] ='PRM'
ncd_prm17['base_item_id'] ='PRM'
ncd_prm18['base_item_id'] ='PRM'
ncd_prm19['base_item_id'] ='PRM'
ncd_prm20['base_item_id'] ='PRM'
ncd_prm21['base_item_id'] ='PRM'
ncd_prm22['base_item_id'] ='PRM'
ncd_prm23['base_item_id'] ='PRM'
ncd_prm24['base_item_id'] ='PRM'
ncd_prm25['base_item_id'] ='PRM'
ncd_prm26['base_item_id'] ='PRM'
ncd_prm27['base_item_id'] ='PRM'
ncd_prm28['base_item_id'] ='PRM'
ncd_prm29['base_item_id'] ='PRM'
ncd_prm30['base_item_id'] ='PRM'

ncd_ltt13['base_item_id'] ='LT_T'
ncd_ltt14['base_item_id'] ='LT_T'
ncd_ltt15['base_item_id'] ='LT_T'
ncd_ltt16['base_item_id'] ='LT_T'
ncd_ltt17['base_item_id'] ='LT_T'
ncd_ltt18['base_item_id'] ='LT_T'
ncd_ltt19['base_item_id'] ='LT_T'
ncd_ltt20['base_item_id'] ='LT_T'
ncd_ltt21['base_item_id'] ='LT_T'
ncd_ltt22['base_item_id'] ='LT_T'
ncd_ltt23['base_item_id'] ='LT_T'
ncd_ltt24['base_item_id'] ='LT_T'
ncd_ltt25['base_item_id'] ='LT_T'
ncd_ltt26['base_item_id'] ='LT_T'
ncd_ltt27['base_item_id'] ='LT_T'
ncd_ltt28['base_item_id'] ='LT_T'
ncd_ltt29['base_item_id'] ='LT_T'
ncd_ltt30['base_item_id'] ='LT_T'

ncd_bst13['base_item_id'] ='BS_T'
ncd_bst14['base_item_id'] ='BS_T'
ncd_bst15['base_item_id'] ='BS_T'
ncd_bst16['base_item_id'] ='BS_T'
ncd_bst17['base_item_id'] ='BS_T'
ncd_bst18['base_item_id'] ='BS_T'
ncd_bst19['base_item_id'] ='BS_T'
ncd_bst20['base_item_id'] ='BS_T'
ncd_bst21['base_item_id'] ='BS_T'
ncd_bst22['base_item_id'] ='BS_T'
ncd_bst23['base_item_id'] ='BS_T'
ncd_bst24['base_item_id'] ='BS_T'
ncd_bst25['base_item_id'] ='BS_T'
ncd_bst26['base_item_id'] ='BS_T'
ncd_bst27['base_item_id'] ='BS_T'
ncd_bst28['base_item_id'] ='BS_T'
ncd_bst29['base_item_id'] ='BS_T'
ncd_bst30['base_item_id'] ='BS_T'

ncd_prmt13['base_item_id'] ='PRM_T'
ncd_prmt14['base_item_id'] ='PRM_T'
ncd_prmt15['base_item_id'] ='PRM_T'
ncd_prmt16['base_item_id'] ='PRM_T'
ncd_prmt17['base_item_id'] ='PRM_T'
ncd_prmt18['base_item_id'] ='PRM_T'
ncd_prmt19['base_item_id'] ='PRM_T'
ncd_prmt20['base_item_id'] ='PRM_T'
ncd_prmt21['base_item_id'] ='PRM_T'
ncd_prmt22['base_item_id'] ='PRM_T'
ncd_prmt23['base_item_id'] ='PRM_T'
ncd_prmt24['base_item_id'] ='PRM_T'
ncd_prmt25['base_item_id'] ='PRM_T'
ncd_prmt26['base_item_id'] ='PRM_T'
ncd_prmt27['base_item_id'] ='PRM_T'
ncd_prmt28['base_item_id'] ='PRM_T'
ncd_prmt29['base_item_id'] ='PRM_T'
ncd_prmt30['base_item_id'] ='PRM_T'

ncd_placeltt13['base_item_id'] ='1LT_T'
ncd_placeltt14['base_item_id'] ='1LT_T'
ncd_placeltt15['base_item_id'] ='1LT_T'
ncd_placeltt16['base_item_id'] ='1LT_T'
ncd_placeltt17['base_item_id'] ='1LT_T'
ncd_placeltt18['base_item_id'] ='1LT_T'
ncd_placeltt19['base_item_id'] ='1LT_T'
ncd_placeltt20['base_item_id'] ='1LT_T'
ncd_placeltt21['base_item_id'] ='1LT_T'
ncd_placeltt22['base_item_id'] ='1LT_T'
ncd_placeltt23['base_item_id'] ='1LT_T'
ncd_placeltt24['base_item_id'] ='1LT_T'
ncd_placeltt25['base_item_id'] ='1LT_T'
ncd_placeltt26['base_item_id'] ='1LT_T'
ncd_placeltt27['base_item_id'] ='1LT_T'
ncd_placeltt28['base_item_id'] ='1LT_T'
ncd_placeltt29['base_item_id'] ='1LT_T'
ncd_placeltt30['base_item_id'] ='1LT_T'

ncd_placelt13['base_item_id'] ='1LT'
ncd_placelt14['base_item_id'] ='1LT'
ncd_placelt15['base_item_id'] ='1LT'
ncd_placelt16['base_item_id'] ='1LT'
ncd_placelt17['base_item_id'] ='1LT'
ncd_placelt18['base_item_id'] ='1LT'
ncd_placelt19['base_item_id'] ='1LT'
ncd_placelt20['base_item_id'] ='1LT'
ncd_placelt21['base_item_id'] ='1LT'
ncd_placelt22['base_item_id'] ='1LT'
ncd_placelt23['base_item_id'] ='1LT'
ncd_placelt24['base_item_id'] ='1LT'
ncd_placelt25['base_item_id'] ='1LT'
ncd_placelt26['base_item_id'] ='1LT'
ncd_placelt27['base_item_id'] ='1LT'
ncd_placelt28['base_item_id'] ='1LT'
ncd_placelt29['base_item_id'] ='1LT'
ncd_placelt30['base_item_id'] ='1LT'

ncd_placebst13['base_item_id'] ='1BS_T'
ncd_placebst14['base_item_id'] ='1BS_T'
ncd_placebst15['base_item_id'] ='1BS_T'
ncd_placebst16['base_item_id'] ='1BS_T'
ncd_placebst17['base_item_id'] ='1BS_T'
ncd_placebst18['base_item_id'] ='1BS_T'
ncd_placebst19['base_item_id'] ='1BS_T'
ncd_placebst20['base_item_id'] ='1BS_T'
ncd_placebst21['base_item_id'] ='1BS_T'
ncd_placebst22['base_item_id'] ='1BS_T'
ncd_placebst23['base_item_id'] ='1BS_T'
ncd_placebst24['base_item_id'] ='1BS_T'
ncd_placebst25['base_item_id'] ='1BS_T'
ncd_placebst26['base_item_id'] ='1BS_T'
ncd_placebst27['base_item_id'] ='1BS_T'
ncd_placebst28['base_item_id'] ='1BS_T'
ncd_placebst29['base_item_id'] ='1BS_T'
ncd_placebst30['base_item_id'] ='1BS_T'

ncd_placebs13['base_item_id'] ='1BS'
ncd_placebs14['base_item_id'] ='1BS'
ncd_placebs15['base_item_id'] ='1BS'
ncd_placebs16['base_item_id'] ='1BS'
ncd_placebs17['base_item_id'] ='1BS'
ncd_placebs18['base_item_id'] ='1BS'
ncd_placebs19['base_item_id'] ='1BS'
ncd_placebs20['base_item_id'] ='1BS'
ncd_placebs21['base_item_id'] ='1BS'
ncd_placebs22['base_item_id'] ='1BS'
ncd_placebs23['base_item_id'] ='1BS'
ncd_placebs24['base_item_id'] ='1BS'
ncd_placebs25['base_item_id'] ='1BS'
ncd_placebs26['base_item_id'] ='1BS'
ncd_placebs27['base_item_id'] ='1BS'
ncd_placebs28['base_item_id'] ='1BS'
ncd_placebs29['base_item_id'] ='1BS'
ncd_placebs30['base_item_id'] ='1BS'

ncd_placehr13['base_item_id'] ='1HR'
ncd_placehr14['base_item_id'] ='1HR'
ncd_placehr15['base_item_id'] ='1HR'
ncd_placehr16['base_item_id'] ='1HR'
ncd_placehr17['base_item_id'] ='1HR'
ncd_placehr18['base_item_id'] ='1HR'
ncd_placehr19['base_item_id'] ='1HR'
ncd_placehr20['base_item_id'] ='1HR'
ncd_placehr21['base_item_id'] ='1HR'
ncd_placehr22['base_item_id'] ='1HR'
ncd_placehr23['base_item_id'] ='1HR'
ncd_placehr24['base_item_id'] ='1HR'
ncd_placehr25['base_item_id'] ='1HR'
ncd_placehr26['base_item_id'] ='1HR'
ncd_placehr27['base_item_id'] ='1HR'
ncd_placehr28['base_item_id'] ='1HR'
ncd_placehr29['base_item_id'] ='1HR'
ncd_placehr30['base_item_id'] ='1HR'

# %%
ncd13 = pd.concat([ncd_box13, ncd_ltt13, ncd_lt13, ncd_bst13, ncd_bs13, ncd_prmt13, ncd_prm13, ncd_placeltt13, ncd_placebst13, ncd_placelt13, ncd_placebs13, ncd_placehr13])
ncd14 = pd.concat([ncd_box14, ncd_ltt14, ncd_lt14, ncd_bst14, ncd_bs14, ncd_prmt14, ncd_prm14, ncd_placeltt14, ncd_placebst14, ncd_placelt14, ncd_placebs14, ncd_placehr14])
ncd15 = pd.concat([ncd_box15, ncd_ltt15, ncd_lt15, ncd_bst15, ncd_bs15, ncd_prmt15, ncd_prm15, ncd_placeltt15, ncd_placebst15, ncd_placelt15, ncd_placebs15, ncd_placehr15])
ncd16 = pd.concat([ncd_box16, ncd_ltt16, ncd_lt16, ncd_bst16, ncd_bs16, ncd_prmt16, ncd_prm16, ncd_placeltt16, ncd_placebst16, ncd_placelt16, ncd_placebs16, ncd_placehr16])
ncd17 = pd.concat([ncd_box17, ncd_ltt17, ncd_lt17, ncd_bst17, ncd_bs17, ncd_prmt17, ncd_prm17, ncd_placeltt17, ncd_placebst17, ncd_placelt17, ncd_placebs17, ncd_placehr17])
ncd18 = pd.concat([ncd_box18, ncd_ltt18, ncd_lt18, ncd_bst18, ncd_bs18, ncd_prmt18, ncd_prm18, ncd_placeltt18, ncd_placebst18, ncd_placelt18, ncd_placebs18, ncd_placehr18])
ncd19 = pd.concat([ncd_box19, ncd_ltt19, ncd_lt19, ncd_bst19, ncd_bs19, ncd_prmt19, ncd_prm19, ncd_placeltt19, ncd_placebst19, ncd_placelt19, ncd_placebs19, ncd_placehr19])
ncd20 = pd.concat([ncd_box20, ncd_ltt20, ncd_lt20, ncd_bst20, ncd_bs20, ncd_prmt20, ncd_prm20, ncd_placeltt20, ncd_placebst20, ncd_placelt20, ncd_placebs20, ncd_placehr20])
ncd21 = pd.concat([ncd_box21, ncd_ltt21, ncd_lt21, ncd_bst21, ncd_bs21, ncd_prmt21, ncd_prm21, ncd_placeltt21, ncd_placebst21, ncd_placelt21, ncd_placebs21, ncd_placehr21])
ncd22 = pd.concat([ncd_box22, ncd_ltt22, ncd_lt22, ncd_bst22, ncd_bs22, ncd_prmt22, ncd_prm22, ncd_placeltt22, ncd_placebst22, ncd_placelt22, ncd_placebs22, ncd_placehr22])
ncd23 = pd.concat([ncd_box23, ncd_ltt23, ncd_lt23, ncd_bst23, ncd_bs23, ncd_prmt23, ncd_prm23, ncd_placeltt23, ncd_placebst23, ncd_placelt23, ncd_placebs23, ncd_placehr23])
ncd24 = pd.concat([ncd_box24, ncd_ltt24, ncd_lt24, ncd_bst24, ncd_bs24, ncd_prmt24, ncd_prm24, ncd_placeltt24, ncd_placebst24, ncd_placelt24, ncd_placebs24, ncd_placehr24])
ncd25 = pd.concat([ncd_box25, ncd_ltt25, ncd_lt25, ncd_bst25, ncd_bs25, ncd_prmt25, ncd_prm25, ncd_placeltt25, ncd_placebst25, ncd_placelt25, ncd_placebs25, ncd_placehr25])
ncd26 = pd.concat([ncd_box26, ncd_ltt26, ncd_lt26, ncd_bst26, ncd_bs26, ncd_prmt26, ncd_prm26, ncd_placeltt26, ncd_placebst26, ncd_placelt26, ncd_placebs26, ncd_placehr26])
ncd27 = pd.concat([ncd_box27, ncd_ltt27, ncd_lt27, ncd_bst27, ncd_bs27, ncd_prmt27, ncd_prm27, ncd_placeltt27, ncd_placebst27, ncd_placelt27, ncd_placebs27, ncd_placehr27])
ncd28 = pd.concat([ncd_box28, ncd_ltt28, ncd_lt28, ncd_bst28, ncd_bs28, ncd_prmt28, ncd_prm28, ncd_placeltt28, ncd_placebst28, ncd_placelt28, ncd_placebs28, ncd_placehr28])
ncd29 = pd.concat([ncd_box29, ncd_ltt29, ncd_lt29, ncd_bst29, ncd_bs29, ncd_prmt29, ncd_prm29, ncd_placeltt29, ncd_placebst29, ncd_placelt29, ncd_placebs29, ncd_placehr29])
ncd30 = pd.concat([ncd_ltt30, ncd_lt30, ncd_bst30, ncd_bs30, ncd_prmt30, ncd_prm30, ncd_placeltt30, ncd_placebst30, ncd_placelt30, ncd_placebs30, ncd_placehr30])

# %%
ncd13['testdomainYn'] = np.where(ncd13['회원번호'].isin(boa13['NCP회원번호']), 'N',
                                       np.where(ncd13['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd13['base_item_id'].str.endswith('FR'), np.nan,
                                                         np.where(ncd13['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd14['testdomainYn'] = np.where(ncd14['회원번호'].isin(boa14['NCP회원번호']), 'N',
                                       np.where(ncd14['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd14['base_item_id'].str.endswith('FR'), np.nan,
                                                         np.where(ncd14['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd15['testdomainYn'] = np.where(ncd15['회원번호'].isin(boa15['NCP회원번호']), 'N',
                                       np.where(ncd15['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd15['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd15['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd16['testdomainYn'] = np.where(ncd16['회원번호'].isin(boa16['NCP회원번호']), 'N',
                                       np.where(ncd16['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd16['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd16['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd17['testdomainYn'] = np.where(ncd17['회원번호'].isin(boa17['NCP회원번호']), 'N',
                                       np.where(ncd17['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd17['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd17['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd18['testdomainYn'] = np.where(ncd18['회원번호'].isin(boa18['NCP회원번호']), 'N',
                                       np.where(ncd18['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd18['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd18['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd19['testdomainYn'] = np.where(ncd19['회원번호'].isin(boa19['NCP회원번호']), 'N',
                                       np.where(ncd19['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd19['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd19['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd20['testdomainYn'] = np.where(ncd20['회원번호'].isin(boa20['NCP회원번호']), 'N',
                                       np.where(ncd20['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd20['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd20['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd21['testdomainYn'] = np.where(ncd21['회원번호'].isin(boa21['NCP회원번호']), 'N',
                                       np.where(ncd21['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd21['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd21['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd22['testdomainYn'] = np.where(ncd22['회원번호'].isin(boa22['NCP회원번호']), 'N',
                                       np.where(ncd22['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd22['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd22['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd23['testdomainYn'] = np.where(ncd23['회원번호'].isin(boa23['NCP회원번호']), 'N',
                                       np.where(ncd23['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd23['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd23['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd24['testdomainYn'] = np.where(ncd24['회원번호'].isin(boa24['NCP회원번호']), 'N',
                                       np.where(ncd24['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd24['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd24['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd25['testdomainYn'] = np.where(ncd25['회원번호'].isin(boa25['NCP회원번호']), 'N',
                                       np.where(ncd25['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd25['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd25['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd26['testdomainYn'] = np.where(ncd26['회원번호'].isin(boa26['NCP회원번호']), 'N',
                                       np.where(ncd26['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd26['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd26['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd27['testdomainYn'] = np.where(ncd27['회원번호'].isin(boa27['NCP회원번호']), 'N',
                                       np.where(ncd27['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd27['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd27['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd28['testdomainYn'] = np.where(ncd28['회원번호'].isin(boa28['NCP회원번호']), 'N',
                                       np.where(ncd28['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd28['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd28['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd29['testdomainYn'] = np.where(ncd29['회원번호'].isin(boa29['NCP회원번호']), 'N',
                                       np.where(ncd29['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd29['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd29['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))
ncd30['testdomainYn'] = np.where(ncd30['회원번호'].isin(boa30['NCP회원번호']), 'N',
                                       np.where(ncd30['base_item_id'].str.endswith('_T'), np.nan, 
                                                np.where(ncd30['base_item_id'].str.endswith('FR'), np.nan, 
                                                         np.where(ncd30['base_item_id'].str.endswith('(Trial)'), np.nan, 'Y')
                                               )
                                      ))

ncd30 = ncd30[ncd30['미터링일시']<20240604]

ncd_box30['testdomainYn'] = np.where(ncd_box30['회원번호'].isin(boa30['NCP회원번호']), 'N',
                                       np.where(ncd_box30['base_item_id'].str.endswith('(Trial)'), np.nan, 
                                                np.where(ncd_box30['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
ncd_box31['testdomainYn'] = np.where(ncd_box31['회원번호'].isin(boa31['NCP회원번호']), 'N',
                                       np.where(ncd_box31['base_item_id'].str.endswith('(Trial)'), np.nan, 
                                                np.where(ncd_box31['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
ncd_box32['testdomainYn'] = np.where(ncd_box32['회원번호'].isin(boa32['NCP회원번호']), 'N',
                                       np.where(ncd_box32['base_item_id'].str.endswith('(Trial)'), np.nan, 
                                                np.where(ncd_box32['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
ncd_box33['testdomainYn'] = np.where(ncd_box33['회원번호'].isin(boa33['NCP회원번호']), 'N',
                                       np.where(ncd_box33['base_item_id'].str.endswith('(Trial)'), np.nan, 
                                                np.where(ncd_box33['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
ncd_box34['testdomainYn'] = np.where(ncd_box34['회원번호'].isin(boa34['NCP회원번호']), 'N',
                                       np.where(ncd_box34['base_item_id'].str.endswith('(Trial)'), np.nan, 
                                                np.where(ncd_box34['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
ncd_box35['testdomainYn'] = np.where(ncd_box35['회원번호'].isin(boa35['NCP회원번호']), 'N',
                                       np.where(ncd_box35['base_item_id'].str.endswith('(Trial)'), np.nan, 
                                                np.where(ncd_box35['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )

# %%
paydb_base30['testdomainYn'] = np.where(paydb_base30['member_no'].isin(boa30['NCP회원번호']), 'N',
                                       np.where(paydb_base30['base_item_id'].str.endswith('_T'), np.nan,
                                                np.where(paydb_base30['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
paydb_base31['testdomainYn'] = np.where(paydb_base31['member_no'].isin(boa31['NCP회원번호']), 'N',
                                       np.where(paydb_base31['base_item_id'].str.endswith('_T'), np.nan,
                                                np.where(paydb_base31['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
paydb_base32['testdomainYn'] = np.where(paydb_base32['member_no'].isin(boa32['NCP회원번호']), 'N',
                                       np.where(paydb_base32['base_item_id'].str.endswith('_T'), np.nan,
                                                np.where(paydb_base32['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
paydb_base33['testdomainYn'] = np.where(paydb_base33['member_no'].isin(boa33['NCP회원번호']), 'N',
                                       np.where(paydb_base33['base_item_id'].str.endswith('_T'), np.nan,
                                                np.where(paydb_base33['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
paydb_base34['testdomainYn'] = np.where(paydb_base34['member_no'].isin(boa34['NCP회원번호']), 'N',
                                       np.where(paydb_base34['base_item_id'].str.endswith('_T'), np.nan,
                                                np.where(paydb_base34['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
paydb_base35['testdomainYn'] = np.where(paydb_base35['member_no'].isin(boa35['NCP회원번호']), 'N',
                                       np.where(paydb_base35['base_item_id'].str.endswith('_T'), np.nan,
                                                np.where(paydb_base35['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
paydb_base36_1['testdomainYn'] = np.where(paydb_base36_1['member_no'].isin(boa36['NCP회원번호']), 'N',
                                       np.where(paydb_base36_1['base_item_id'].str.endswith('_T'), np.nan,
                                                np.where(paydb_base36_1['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )
paydb_base36_2['testdomainYn'] = np.where(paydb_base36_2['member_no'].isin(boa36['NCP회원번호']), 'N',
                                       np.where(paydb_base36_2['base_item_id'].str.endswith('_T'), np.nan,
                                                np.where(paydb_base36_2['base_item_id'].str.endswith('FR'), np.nan, 'Y')
                                               )
                                      )

# %%
paydb_option30['testdomainYn'] = np.where(paydb_option30['member_no'].isin(boa30['NCP회원번호']), 'N', 'Y')
paydb_option31['testdomainYn'] = np.where(paydb_option31['member_no'].isin(boa31['NCP회원번호']), 'N', 'Y')
paydb_option32['testdomainYn'] = np.where(paydb_option32['member_no'].isin(boa32['NCP회원번호']), 'N', 'Y')
paydb_option33['testdomainYn'] = np.where(paydb_option33['member_no'].isin(boa33['NCP회원번호']), 'N', 'Y')
paydb_option34['testdomainYn'] = np.where(paydb_option34['member_no'].isin(boa34['NCP회원번호']), 'N', 'Y')
paydb_option35['testdomainYn'] = np.where(paydb_option35['member_no'].isin(boa35['NCP회원번호']), 'N', 'Y')
paydb_option36_1['testdomainYn'] = np.where(paydb_option36_1['member_no'].isin(boa36['NCP회원번호']), 'N', 'Y')
paydb_option36_2['testdomainYn'] = np.where(paydb_option36_2['member_no'].isin(boa36['NCP회원번호']), 'N', 'Y')

# %%
paydb_option30.rename(columns = {'add_item_id':'base_item_id'},inplace=True)
paydb_option31.rename(columns= {'add_item_id':'base_item_id'},inplace=True)
paydb_option32.rename(columns = {'add_item_id':'base_item_id'},inplace=True)
paydb_option33.rename(columns = {'add_item_id':'base_item_id'},inplace=True)
paydb_option34.rename(columns = {'add_item_id':'base_item_id'},inplace=True)
paydb_option35.rename(columns = {'add_item_id':'base_item_id'},inplace=True)
paydb_option36_1.rename(columns = {'add_item_id':'base_item_id'},inplace=True)
paydb_option36_2.rename(columns = {'add_item_id':'base_item_id'},inplace=True)

# %%
paydb30 = pd.concat([paydb_base30, paydb_option30])
paydb31 = pd.concat([paydb_base31, paydb_option31])
paydb32 = pd.concat([paydb_base32, paydb_option32])
paydb33 = pd.concat([paydb_base33, paydb_option33])
paydb34 = pd.concat([paydb_base34, paydb_option34])
paydb35 = pd.concat([paydb_base35, paydb_option35])
paydb36 = pd.concat([paydb_base36_1, paydb_base36_2, paydb_option36_1, paydb_option36_2])

# %%
print(boa1.columns)
print(ncd13.columns)
print(paydb30.columns)
# Out:
# Index(['NCP회원번호', 'calc_ymd', '상품구분', '상품명', '단위사용량', '채널', '파트너회원번호',
#        'testdomainYn'],
#       dtype='object')
# Index(['회원번호', '회원그룹코드', '회원그룹명', '파트너사회원번호', '청구유형코드', '청구유형코드명', '청구유형상세코드',
#        '청구유형상세코드명', '인스턴스유형코드', '인스턴스유형코드명', '미터링유형코드', '미터링유형코드명', '계약번호',
#        '인스턴스번호', '리전번호', '리전명', '계약상품일련번호', '약정여부', '요금', '미터링일시', '사용량',
#        '상품사이즈', '상품갯수', '이벤트사용량', '사용량단위코드', '사용량단위명', 'base_item_id',
#        'testdomainYn'],
#       dtype='object')
# Index(['domain_id', 'calc_ymd', 'subscription_id', 'tenant_id', 'seller_id',
#        'base_item_id', 'pmnt_plan', 'pmnt_plan_start_ymd', 'pmnt_plan_end_ymd',
#        'license_count', 'user_count', 'max_user_count', 'domain_status',
#        'stop_payment_yn', 'member_no', 'instance_no', 'reg_ymdt',
#        'testdomainYn', 'sub_item_id', 'item_count', 'usage_count'],
#       dtype='object')

# %%
boa1.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa2.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa3.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa4.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa5.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa6.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa7.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa8.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa9.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa10.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa11.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
boa12.rename(columns = {'NCP회원번호':'member_no','상품구분':'item_group','상품명':'item_id','단위사용량':'user_count','파트너회원번호':'파트너사회원번호'},inplace=True)
ncd13.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd14.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd15.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd16.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd17.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd18.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd19.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd20.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd21.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd22.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd23.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd24.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd25.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd26.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd27.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd28.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd29.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd30.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd_box30.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd_box31.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd_box32.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd_box33.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd_box34.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
ncd_box35.rename(columns = {'회원번호':'member_no','base_item_id':'item_id','미터링일시':'calc_ymd','사용량':'user_count'},inplace=True)
paydb30.rename(columns = {'base_item_id':'item_id'},inplace=True)
paydb31.rename(columns = {'base_item_id':'item_id'},inplace=True)
paydb32.rename(columns = {'base_item_id':'item_id'},inplace=True)
paydb33.rename(columns = {'base_item_id':'item_id'},inplace=True)
paydb34.rename(columns = {'base_item_id':'item_id'},inplace=True)
paydb35.rename(columns = {'base_item_id':'item_id'},inplace=True)
paydb36.rename(columns = {'base_item_id':'item_id'},inplace=True)

# %%
ncd13.loc[:,'calc_ymd'] = ncd13.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd13.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd13.loc[:,'calc_ymd'].astype(str).str[6:]
ncd14.loc[:,'calc_ymd'] = ncd14.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd14.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd14.loc[:,'calc_ymd'].astype(str).str[6:]
ncd15.loc[:,'calc_ymd'] = ncd15.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd15.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd15.loc[:,'calc_ymd'].astype(str).str[6:]
ncd16.loc[:,'calc_ymd'] = ncd16.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd16.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd16.loc[:,'calc_ymd'].astype(str).str[6:]
ncd17.loc[:,'calc_ymd'] = ncd17.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd17.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd17.loc[:,'calc_ymd'].astype(str).str[6:]
ncd18.loc[:,'calc_ymd'] = ncd18.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd18.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd18.loc[:,'calc_ymd'].astype(str).str[6:]
ncd19.loc[:,'calc_ymd'] = ncd19.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd19.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd19.loc[:,'calc_ymd'].astype(str).str[6:]
ncd20.loc[:,'calc_ymd'] = ncd20.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd20.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd20.loc[:,'calc_ymd'].astype(str).str[6:]
ncd21.loc[:,'calc_ymd'] = ncd21.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd21.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd21.loc[:,'calc_ymd'].astype(str).str[6:]
ncd22.loc[:,'calc_ymd'] = ncd22.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd22.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd22.loc[:,'calc_ymd'].astype(str).str[6:]
ncd23.loc[:,'calc_ymd'] = ncd23.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd23.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd23.loc[:,'calc_ymd'].astype(str).str[6:]
ncd24.loc[:,'calc_ymd'] = ncd24.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd24.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd24.loc[:,'calc_ymd'].astype(str).str[6:]
ncd25.loc[:,'calc_ymd'] = ncd25.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd25.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd25.loc[:,'calc_ymd'].astype(str).str[6:]
ncd26.loc[:,'calc_ymd'] = ncd26.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd26.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd26.loc[:,'calc_ymd'].astype(str).str[6:]
ncd27.loc[:,'calc_ymd'] = ncd27.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd27.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd27.loc[:,'calc_ymd'].astype(str).str[6:]
ncd28.loc[:,'calc_ymd'] = ncd28.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd28.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd28.loc[:,'calc_ymd'].astype(str).str[6:]
ncd29.loc[:,'calc_ymd'] = ncd29.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd29.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd29.loc[:,'calc_ymd'].astype(str).str[6:]
ncd30.loc[:,'calc_ymd'] = ncd30.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd30.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd30.loc[:,'calc_ymd'].astype(str).str[6:]
ncd_box30.loc[:,'calc_ymd'] = ncd_box30.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd_box30.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd_box30.loc[:,'calc_ymd'].astype(str).str[6:]
ncd_box31.loc[:,'calc_ymd'] = ncd_box31.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd_box31.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd_box31.loc[:,'calc_ymd'].astype(str).str[6:]
ncd_box32.loc[:,'calc_ymd'] = ncd_box32.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd_box32.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd_box32.loc[:,'calc_ymd'].astype(str).str[6:]
ncd_box33.loc[:,'calc_ymd'] = ncd_box33.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd_box33.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd_box33.loc[:,'calc_ymd'].astype(str).str[6:]
ncd_box34.loc[:,'calc_ymd'] = ncd_box34.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd_box34.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd_box34.loc[:,'calc_ymd'].astype(str).str[6:]
ncd_box35.loc[:,'calc_ymd'] = ncd_box35.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd_box35.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd_box35.loc[:,'calc_ymd'].astype(str).str[6:]
# Out:
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_99737/2903398509.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['2023-01-01' '2023-01-02' '2023-01-03' ... '2023-01-31' '2023-01-31'
#  '2023-01-31']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   ncd13.loc[:,'calc_ymd'] = ncd13.loc[:,'calc_ymd'].astype(str).str[:4] + '-' + ncd13.loc[:,'calc_ymd'].astype(str).str[4:6] + '-' + ncd13.loc[:,'calc_ymd'].astype(str).str[6:]
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_99737/2903398509.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['2023-02-01' '2023-02-02' '2023-02-03' ... '2023-02-28' '2023-02-27'
#  '2023-02-28']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# ...

# %%
free1 = pd.read_csv('/Users/user/Documents/진행중 업무/2023년 Free (주간).csv')
free2 = pd.read_csv('/Users/user/Documents/진행중 업무/2024년 주간 프리 (2024년 6월 3일까지).csv')
free1 = free1.rename(columns = {'base_item_id':'item_id'})
free2 = free2.rename(columns = {'base_item_id':'item_id'})

# %%
data = pd.concat([boa1, boa2, boa3, boa4, boa5, boa6, boa7, boa8, boa9, boa10, 
                  boa11, boa12, ncd13, ncd14, ncd15, ncd16, ncd17, ncd18, ncd19, ncd20,
                  ncd21, ncd22, ncd23, ncd24, ncd25, ncd26, ncd27, ncd28, ncd29, ncd30, 
                  paydb30, paydb31, paydb32, paydb33, paydb34, paydb35, paydb36, free1, free2])

# %%
ncd_box30['item_group']='WORKS DRIVE'
ncd_box31['item_group']='WORKS DRIVE'
ncd_box32['item_group']='WORKS DRIVE'
ncd_box33['item_group']='WORKS DRIVE'
ncd_box34['item_group']='WORKS DRIVE'
ncd_box35['item_group']='WORKS DRIVE'

# %%
data['item_group'] = 'NAVER WORKS'
data.loc[data['item_id'].str.startswith('Workbox'),'item_group']='WORKS DRIVE'
data.loc[data['item_id'].str.startswith('WORKPLACE'),'item_group']='WORKPLACE'
data.loc[data['item_id'].isin(['DRV_T','DRV_LT','DRV_STD','DRV_STD_P','OCE2']),'item_group']='WORKS DRIVE'
data.loc[data['item_id'].isin(['CNT_T','CNT_TM','CNT_LT','CNT_EP','CNT_BZ','QTA_O','QTA_M']),'item_group']='WORKS ClovaNote'
data.loc[data['item_id'].isin(['1LT_T','1LT','1BS_T','1BS','1HR','APP_T','ATT_T','FIN_T','PAY_T','APP_STD','ATT_STD','FIN_STD','PAY_STD','TXI','PLG','RSV','COC']),'item_group']='WORKPLACE'
data.loc[data['item_id'].isna() | (data['item_id'] == ''), 'item_group'] = ''

# %%
data = pd.concat([data, ncd_box30, ncd_box31, ncd_box32, ncd_box33, ncd_box34, ncd_box35])

# %%
data['item_id'] = data['item_id'].astype(str).str.lstrip('1')
data['ncpIdYn'] = np.where(data['member_no'].isna(), 'N', 'Y')
columns_to_move = ['member_no', 'item_group', 'item_id', 'calc_ymd', 'user_count','testdomainYn','ncpIdYn']
data = data[columns_to_move + [col for col in data.columns if col not in columns_to_move]]
data['item_id'].unique()
# Out:
# array(['NAVER WORKS BASIC', 'NAVER WORKS PREMIUM', 'WORKPLACE Basic',
#        'WORKPLACE 연동법인카드', 'NAVER WORKS LITE', 'WORKPLACE Collabo',
#        'Workbox Basic', 'WORKPLACE Finance', 'WORKPLACE HR',
#        'Workbox 공용용량', 'WORKPLACE Collabo+', 'WORKPLACE 아르바이트',
#        'WORKPLACE AI OCR', 'NAVER WORKS VOLUME', 'WORKPLACE Lite', '-',
#        'WORKPLACE Collabo Lite', 'Workbox Online Editor',
#        'WORKPLACE 드라이브볼륨용량', 'WORKPLACE 공용용량', 'NAVER WORKS ARCHIVING',
#        'WORKPLACE 업무지원(유밥-법정필수&직무/역량개발)', 'WORKPLACE 업무지원(유밥-법정필수)',
#        'WORKPLACE 업무지원', 'WORKPLACE 업무지원(유밥-법정필수&산업안전&직무/역량개발)',
#        '부가서비스(전자계약)', 'WORKPLACE 전자세금계산서', 'WORKPLACE 업무지원(투디)',
#        'WORKPLACE 업무지원(미리캔버스Pro)', 'WORKPLACE 업무지원(로아이)',
#        'WORKPLACE 업무지원(유밥-법정필수&산업안전)', 'WORKBOX Paid Volume', 'WORKBOX',
#        'WORKBOX (Trial)', 'LT_T', 'LT', 'BS_T', 'BS', 'PRM_T', 'PRM',
#        'HR', 'COR_T', 'COR_STD', 'COR_STD_P', 'STG_1T', 'APP_T', 'DRV_T',
# ...

# %%
data.to_csv('/Users/user/Documents/진행중 업무/data_integration.csv',index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.rcParams['font.family'] = 'AppleGothic'

pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('/Users/user/Documents/진행중 업무/data_integration.csv')
# Out:
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_93205/1453651056.py:1: DtypeWarning: Columns (4,5,7,8,9,11,12,13,14,15,16,17,18,22,24,29,30,36,37,43,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/Users/user/Documents/진행중 업무/data_integration.csv')

# %%
paydb_base_2022 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/기본 상품/2022년 월간 base (마지막 주 수요일 기준).csv')
paydb_base_2023 = pd.read_csv('/Users/user/Documents/진행중 업무/2023년 주간 base.csv')
paydb_base_2024 = pd.read_csv('/Users/user/Documents/진행중 업무/2024년 base(~2024.6.3) 주간.csv')

paydb_option_2022 = pd.read_csv('/Users/user/Documents/진행중 업무/데이터/Paydb/옵션 상품/2022년 월간 option (마지막 주 수요일 기준).csv')
paydb_option_2023 = pd.read_csv('/Users/user/Documents/진행중 업무/2023년 option(주간).csv')
paydb_option_2024 = pd.read_csv('/Users/user/Documents/진행중 업무/2024년 option 주간(~2024.6.3).csv')

# %%
data = data[['member_no', 'item_group', 'item_id', 'calc_ymd', 'user_count', 'testdomainYn', 'ncpIdYn', 'domain_id', 'tenant_id', 'seller_id', 'pmnt_plan_start_ymd', 'pmnt_plan_end_ymd','회원그룹코드','채널','파트너사회원번호']]
paydb_base_222324 = pd.concat([paydb_base_2022, paydb_base_2023, paydb_base_2024])
paydb_base_222324 = paydb_base_222324.rename(columns = {'base_item_id':'item_id'})
paydb_option_222324 = pd.concat([paydb_option_2022, paydb_option_2023, paydb_option_2024])
paydb_option_222324 = paydb_option_222324.rename(columns = {'add_item_id':'item_id'})

# %%
base = data[~data['item_id'].isin(['NAVER WORKS ARCHIVING',
       'WORKPLACE 업무지원(유밥-법정필수&직무/역량개발)', 'WORKPLACE 업무지원(유밥-법정필수)',
       'WORKPLACE 업무지원', 'WORKPLACE 업무지원(유밥-법정필수&산업안전&직무/역량개발)',
       '부가서비스(전자계약)', 'WORKPLACE 전자세금계산서', 'WORKPLACE 업무지원(투디)',
       'WORKPLACE 업무지원(미리캔버스Pro)', 'WORKPLACE 업무지원(로아이)', 'WORKBOX Paid Volume',
       'WORKPLACE 업무지원(유밥-법정필수&산업안전)','NAVER WORKS VOLUME','WORKPLACE 연동법인카드','WORKPLACE 아르바이트','WORKPLACE 드라이브볼륨용량','WORKPLACE 공용용량','WORKPLACE AI OCR','Workbox 공용용량','Workbox Online Editor','ACV','ACV4','ACV5','OCE1','OCE2','QTA_O','QTA_M','TXI','PLG','RSV','COC','SSTG'])]
option = data[data['item_id'].isin(['NAVER WORKS ARCHIVING',
       'WORKPLACE 업무지원(유밥-법정필수&직무/역량개발)', 'WORKPLACE 업무지원(유밥-법정필수)',
       'WORKPLACE 업무지원', 'WORKPLACE 업무지원(유밥-법정필수&산업안전&직무/역량개발)',
       '부가서비스(전자계약)', 'WORKPLACE 전자세금계산서', 'WORKPLACE 업무지원(투디)',
       'WORKPLACE 업무지원(미리캔버스Pro)', 'WORKPLACE 업무지원(로아이)', 'WORKBOX Paid Volume',
       'WORKPLACE 업무지원(유밥-법정필수&산업안전)','NAVER WORKS VOLUME','WORKPLACE 연동법인카드','WORKPLACE 아르바이트','WORKPLACE 드라이브볼륨용량','WORKPLACE 공용용량','WORKPLACE AI OCR','Workbox 공용용량','Workbox Online Editor','ACV','ACV4','ACV5','OCE1','OCE2','QTA_O','QTA_M','TXI','PLG','RSV','COC','SSTG'])]

# %%
paydb_base_222324['item_group']='NAVER WORKS'
paydb_option_222324['item_group']='NAVER WORKS'
paydb_base_222324 = paydb_base_222324.drop_duplicates(subset=['member_no','item_group'],keep='first')
paydb_option_222324 = paydb_option_222324.drop_duplicates(subset=['member_no','item_group'],keep='first')
columns_to_update = ['domain_id', 'tenant_id', 'seller_id', 'pmnt_plan_start_ymd', 'pmnt_plan_end_ymd']
paydb_base_222324 = paydb_base_222324[['member_no', 'item_group'] + columns_to_update]
paydb_option_222324 = paydb_option_222324[['member_no', 'item_group'] + columns_to_update]
base = pd.merge(base, paydb_base_222324, on = ['member_no','item_group'], how = 'left')
option = pd.merge(option, paydb_option_222324, on = ['member_no','item_group'], how = 'left')
base.loc[(base['채널'].isin(['온라인 매출','영업 매출','관계사 기타']))|(base['회원그룹코드'].isin(['GEN','SLS','INTL'])),'seller_id_x'] = 0
option.loc[(option['채널'].isin(['온라인 매출','영업 매출','관계사 기타']))|(option['회원그룹코드'].isin(['GEN','SLS','INTL'])),'seller_id_x'] = 0

# %%
base['domain_id_x'] = base['domain_id_x'].fillna(base['domain_id_y'])
base['tenant_id_x'] = base['tenant_id_x'].fillna(base['tenant_id_y'])
base['seller_id_x'] = base['seller_id_x'].fillna(base['seller_id_y'])
base['pmnt_plan_start_ymd_x'] = base['pmnt_plan_start_ymd_x'].fillna(base['pmnt_plan_start_ymd_y'])
base['pmnt_plan_end_ymd_x'] = base['pmnt_plan_end_ymd_x'].fillna(base['pmnt_plan_end_ymd_y'])

option['domain_id_x'] = option['domain_id_x'].fillna(option['domain_id_y'])
option['tenant_id_x'] = option['tenant_id_x'].fillna(option['tenant_id_y'])
option['seller_id_x'] = option['seller_id_x'].fillna(option['seller_id_y'])
option['pmnt_plan_start_ymd_x'] = option['pmnt_plan_start_ymd_x'].fillna(option['pmnt_plan_start_ymd_y'])
option['pmnt_plan_end_ymd_x'] = option['pmnt_plan_end_ymd_x'].fillna(option['pmnt_plan_end_ymd_y'])

# %%
base = base.drop(['domain_id_y','tenant_id_y','seller_id_y','pmnt_plan_start_ymd_y','pmnt_plan_end_ymd_y','회원그룹코드','채널'],axis=1)
base = base.rename(columns = {'domain_id_x':'domain_id','tenant_id_x':'tenant_id','seller_id_x':'seller_id','pmnt_plan_start_ymd_x':'pmnt_plan_start_ymd','pmnt_plan_end_ymd_x':'pmnt_plan_end_ymd'})
option = option.drop(['domain_id_y','tenant_id_y','seller_id_y','pmnt_plan_start_ymd_y','pmnt_plan_end_ymd_y','회원그룹코드','채널'],axis=1)
option = option.rename(columns = {'domain_id_x':'domain_id','tenant_id_x':'tenant_id','seller_id_x':'seller_id','pmnt_plan_start_ymd_x':'pmnt_plan_start_ymd','pmnt_plan_end_ymd_x':'pmnt_plan_end_ymd'})

# %%
base['domain_id'] = base['domain_id'].fillna(base['member_no'].astype(str).fillna('') + '(ncp)')
option['domain_id'] = option['domain_id'].fillna(option['member_no'].astype(str).fillna('') + '(ncp)')
base['seller_id'] = base['seller_id'].fillna(base['파트너사회원번호'].astype(str).fillna('') + '(ncp)')
option['seller_id'] = option['seller_id'].fillna(option['파트너사회원번호'].astype(str).fillna('') + '(ncp)')
base = base.drop('파트너사회원번호', axis = 1)
option = option.drop('파트너사회원번호', axis = 1)

# %%
base.to_csv('/Users/user/Documents/진행중 업무/integrated_data_base.csv',index=False)
option.to_csv('/Users/user/Documents/진행중 업무/integrated_data_option.csv',index=False)

# %%
#월요일 요청사항 반영

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.rcParams['font.family'] = 'AppleGothic'

# %%
base = pd.read_csv('/Users/user/Documents/진행중 업무/integrated_data_base.csv')
option = pd.read_csv('/Users/user/Documents/진행중 업무/integrated_data_option.csv')
# Out:
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_36487/3968052.py:1: DtypeWarning: Columns (4,5,7,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   base = pd.read_csv('/Users/user/Documents/진행중 업무/integrated_data_base.csv')
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_36487/3968052.py:2: DtypeWarning: Columns (7,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   option = pd.read_csv('/Users/user/Documents/진행중 업무/integrated_data_option.csv')

# %%
from datetime import datetime

base.loc[base['item_group']=='NAVER WORKS','item_group'] = '웍스코어'
base.loc[base['item_group']=='WORKS DRIVE','item_group'] = '드라이브'
base.loc[base['item_group']=='WORKPLACE','item_group'] = '경영지원'
base.loc[base['item_group']=='WORKS ClovaNote','item_group'] = '클로바노트'
base.loc[base['item_id'].isin(['ATT_T','ATT_STD']),'item_group'] = '근태'
base.loc[base['item_id'].isin(['FIN_T','FIN_STD']),'item_group'] = '재무'
base.loc[base['item_id'].isin(['HR','PAY_T','PAY_STD']),'item_group'] = '급여'
base.loc[base['item_id'].str.startswith('WLS'),'item_group'] = 'WLS'
base.loc[base['item_id'].str.startswith('STG'),'item_group'] = 'STG'
base = base.copy()
base['odPartnerStatus'] = np.where(base['seller_id']==0,'OD','Partner')
base['groupType'] = np.where(base['item_id'].str.endswith('_T'),'Trial',
                                        np.where(base['item_id'].str.endswith('FR'),'Free','Paid'))
base['calc_ymd'] = pd.to_datetime(base['calc_ymd'])
start_date = datetime(2023, 1, 1)
base['date_code'] = (base['calc_ymd'] - start_date).dt.days + 91
base.loc[base['calc_ymd'].astype(str).str[0:4] =='2022','date_code'] = base['calc_ymd'].astype(str).str[5:7].astype(int) * 7
base['plan_prefix'] = base['item_id'].str[0:2]
base
# Out:
#           member_no item_group              item_id   calc_ymd user_count  \
# 0         2662051.0       웍스코어    NAVER WORKS BASIC 2022-01-26          2
# 1         2694084.0       웍스코어    NAVER WORKS BASIC 2022-01-26          2
# 2         2696523.0       웍스코어  NAVER WORKS PREMIUM 2022-01-26          2
# 3         2716896.0       웍스코어    NAVER WORKS BASIC 2022-01-26       9.87
# 4         2716896.0       경영지원      WORKPLACE Basic 2022-01-26       9.87
# ...             ...        ...                  ...        ...        ...
# 43083866  3302861.0       드라이브              WORKBOX 2024-11-03    86400.0
# 43083867  3302861.0       드라이브              WORKBOX 2024-11-04    86400.0
# 43083868  3302861.0       드라이브              WORKBOX 2024-11-05    86400.0
# 43083869  3302861.0       드라이브              WORKBOX 2024-11-06    86400.0
# 43083870  3302861.0       드라이브              WORKBOX 2024-11-07    33354.0
#
#          testdomainYn ncpIdYn       domain_id  tenant_id       seller_id  \
# ...

# %%
base_add_days = base.copy()
rows_to_duplicate = base_add_days[base_add_days['date_code'] == 84]
duplicated_rows = pd.concat(
    [rows_to_duplicate.assign(date_code=code) for code in range(85, 91)],
    ignore_index=True
)
base_add_days = pd.concat([base_add_days, duplicated_rows], ignore_index=True)
base_add_days['date_code'] = base_add_days['date_code'] + 7
base_add_days
# Out:
#           member_no item_group              item_id   calc_ymd user_count  \
# 0         2662051.0       웍스코어    NAVER WORKS BASIC 2022-01-26          2
# 1         2694084.0       웍스코어    NAVER WORKS BASIC 2022-01-26          2
# 2         2696523.0       웍스코어  NAVER WORKS PREMIUM 2022-01-26          2
# 3         2716896.0       웍스코어    NAVER WORKS BASIC 2022-01-26       9.87
# 4         2716896.0       경영지원      WORKPLACE Basic 2022-01-26       9.87
# ...             ...        ...                  ...        ...        ...
# 43242224  2765092.0       드라이브        Workbox Basic 2022-12-28        2.0
# 43242225  2791109.0       드라이브        Workbox Basic 2022-12-28        1.0
# 43242226  2821760.0       드라이브        Workbox Basic 2022-12-28        1.0
# 43242227  2918557.0       드라이브        Workbox Basic 2022-12-28        3.0
# 43242228  2764545.0       드라이브        Workbox Basic 2022-12-28        1.0
#
#          testdomainYn ncpIdYn       domain_id  tenant_id     seller_id  \
# ...

# %%
base['domain_id_num'] = base['domain_id'].astype(str).str.split('(').str[0].astype(float).astype(int)
base_add_days['domain_id_num'] = base_add_days['domain_id'].astype(str).str.split('(').str[0].astype(float).astype(int)

# %%
percentile_thresholds = []
for i in range(10, 101, 10):
    percentile_value = base['domain_id_num'].quantile(i / 100)
    percentile_thresholds.append(percentile_value)

percentile_thresholds
# Out:
# [85683.0,
#  139747.0,
#  216783.0,
#  1054432.0,
#  300022136.0,
#  300055955.0,
#  300090159.0,
#  300114443.0,
#  300136515.0,
#  300186703.0]

# %%
base0 = base[(base['domain_id_num'].isna())]
base1 = base[(base['domain_id_num']<=percentile_thresholds[0])]
base2 = base[(base['domain_id_num']<=percentile_thresholds[1])&(base['domain_id_num']>percentile_thresholds[0])]
base3 = base[(base['domain_id_num']<=percentile_thresholds[2])&(base['domain_id_num']>percentile_thresholds[1])]
base4 = base[(base['domain_id_num']<=percentile_thresholds[3])&(base['domain_id_num']>percentile_thresholds[2])]
base5 = base[(base['domain_id_num']<=percentile_thresholds[4])&(base['domain_id_num']>percentile_thresholds[3])]
base6 = base[(base['domain_id_num']<=percentile_thresholds[5])&(base['domain_id_num']>percentile_thresholds[4])]
base7 = base[(base['domain_id_num']<=percentile_thresholds[6])&(base['domain_id_num']>percentile_thresholds[5])]
base8 = base[(base['domain_id_num']<=percentile_thresholds[7])&(base['domain_id_num']>percentile_thresholds[6])]
base9 = base[(base['domain_id_num']<=percentile_thresholds[8])&(base['domain_id_num']>percentile_thresholds[7])]
base10 = base[(base['domain_id_num']>percentile_thresholds[8])]

base_add_days1 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[0])]
base_add_days2 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[1])&(base_add_days['domain_id_num']>percentile_thresholds[0])]
base_add_days3 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[2])&(base_add_days['domain_id_num']>percentile_thresholds[1])]
base_add_days4 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[3])&(base_add_days['domain_id_num']>percentile_thresholds[2])]
base_add_days5 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[4])&(base_add_days['domain_id_num']>percentile_thresholds[3])]
base_add_days6 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[5])&(base_add_days['domain_id_num']>percentile_thresholds[4])]
base_add_days7 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[6])&(base_add_days['domain_id_num']>percentile_thresholds[5])]
base_add_days8 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[7])&(base_add_days['domain_id_num']>percentile_thresholds[6])]
base_add_days9 = base_add_days[(base_add_days['domain_id_num']<=percentile_thresholds[8])&(base_add_days['domain_id_num']>percentile_thresholds[7])]
base_add_days10 = base_add_days[(base_add_days['domain_id_num']>percentile_thresholds[8])]

# %%
merged_base1 = pd.merge(
    base1, base_add_days1,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base2 = pd.merge(
    base2, base_add_days2,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base3 = pd.merge(
    base3, base_add_days3,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base4 = pd.merge(
    base4, base_add_days4,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base5 = pd.merge(
    base5, base_add_days5,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base6 = pd.merge(
    base6, base_add_days6,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base7 = pd.merge(
    base7, base_add_days7,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base8 = pd.merge(
    base8, base_add_days8,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base9 = pd.merge(
    base9, base_add_days9,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)
merged_base10 = pd.merge(
    base10, base_add_days10,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','plan_prefix'],
    suffixes=('_cr', '_bf')
)

# %%
from datetime import timedelta
base0 = base0.rename(columns = {'calc_ymd':'calc_ymd_cr','member_no':'member_no_cr','item_id':'item_id_cr','user_count':'user_count_cr','testdomainYn':'testdomainYn_cr','ncpIdYn':'ncpIdYn_cr','tenant_id':'tenant_id_cr','seller_id':'seller_id_cr','pmnt_plan_start_ymd':'pmnt_plan_start_ymd_cr','pmnt_plan_end_ymd':'pmnt_plan_end_ymd_cr','odPartnerStatus':'odPartnerStatus_cr','groupType':'groupType_cr'})
merged_base = pd.concat([base0, merged_base1, merged_base2, merged_base3, merged_base4, merged_base5, merged_base6, merged_base7, merged_base8, merged_base9, merged_base10])
merged_base['calc_ymd_bf'] = merged_base['calc_ymd_bf'] + timedelta(days=7)
merged_base['calc_ymd_cr'] = merged_base['calc_ymd_cr'].fillna(merged_base['calc_ymd_bf'])
merged_base = merged_base[~merged_base['date_code'].between(85, 90)]
columns_to_move = ['domain_id', 'calc_ymd_cr', 'item_group']
merged_base = merged_base[columns_to_move + [col for col in merged_base.columns if col not in columns_to_move]]
merged_base
# Out:
#            domain_id calc_ymd_cr item_group  member_no_cr item_id_cr  \
# 0                7.0  2024-06-14       웍스코어           NaN      COR_T
# 1                7.0  2024-06-15       웍스코어           NaN      COR_T
# 2                7.0  2024-06-16       웍스코어           NaN      COR_T
# 3                7.0  2024-06-17       웍스코어           NaN      COR_T
# 4                7.0  2024-06-18       웍스코어           NaN      COR_T
# ...              ...         ...        ...           ...        ...
# 4683043  300149779.0  2024-06-05       웍스코어           NaN        NaN
# 4683044  300149780.0  2024-05-29       웍스코어     3341974.0         FR
# 4683045  300149780.0  2024-06-05       웍스코어           NaN        NaN
# 4683046  300149781.0  2024-05-29       웍스코어     3341978.0         FR
# 4683047  300149781.0  2024-06-05       웍스코어           NaN        NaN
#
#         user_count_cr testdomainYn_cr ncpIdYn_cr  tenant_id_cr seller_id_cr  \
# ...

# %%
merged_base = merged_base.drop(['date_code','calc_ymd_bf','plan_prefix','domain_id_num_cr','domain_id_num_bf'],axis=1)
merged_base = merged_base.rename(columns = {'domain_id':'domainId','calc_ymd_cr':'date','item_group':'productGroup','member_no_cr':'ncpId_cr','member_no_bf':'ncpId_bf','item_id_cr':'plan_cr','item_id_bf':'plan_bf',
                                            'user_count_cr':'userCount_cr','user_count_bf':'userCount_bf','testdomainYn_cr':'testdomainyn_cr','testdomainYn_bf':'testdomainyn_bf','tenant_id_cr':'tenantId_cr','tenant_id_bf':'tenantId_bf',
                                            'seller_id_cr':'partnerDomainId_cr','seller_id_bf':'partnerDomainId_bf','pmnt_plan_start_ymd_cr':'paymentPlanStartDate_cr','pmnt_plan_start_ymd_bf':'paymentPlanStartDate_bf',
                                            'pmnt_plan_end_ymd_cr':'paymentPlanEndDate_cr','pmnt_plan_end_ymd_bf':'paymentPlanEndDate_bf'})

# %%
merged_base
# Out:
#             domainId       date productGroup   ncpId_cr plan_cr userCount_cr  \
# 0                7.0 2024-06-14         웍스코어        NaN   COR_T      11678.0
# 1                7.0 2024-06-15         웍스코어        NaN   COR_T      11678.0
# 2                7.0 2024-06-16         웍스코어        NaN   COR_T      11678.0
# 3                7.0 2024-06-17         웍스코어        NaN   COR_T      11672.0
# 4                7.0 2024-06-18         웍스코어        NaN   COR_T      11672.0
# ...              ...        ...          ...        ...     ...          ...
# 4683043  300149779.0 2024-06-05         웍스코어        NaN     NaN          NaN
# 4683044  300149780.0 2024-05-29         웍스코어  3341974.0      FR          1.0
# 4683045  300149780.0 2024-06-05         웍스코어        NaN     NaN          NaN
# 4683046  300149781.0 2024-05-29         웍스코어  3341978.0      FR          1.0
# 4683047  300149781.0 2024-06-05         웍스코어        NaN     NaN          NaN
#
# ...

# %%
merged_base[merged_base['domainId']=='0.0(ncp)']
# Out:
#          domainId       date productGroup  ncpId_cr plan_cr userCount_cr  \
# 3420206  0.0(ncp) 2022-01-26         웍스코어       0.0       -            -
# 3420207  0.0(ncp) 2022-01-26         웍스코어       0.0       -            -
# 3420208  0.0(ncp) 2022-01-26         웍스코어       0.0       -            -
# 3420209  0.0(ncp) 2022-01-26         웍스코어       0.0       -            -
# 3420210  0.0(ncp) 2022-02-02         웍스코어       NaN     NaN          NaN
# 3420211  0.0(ncp) 2022-02-02         웍스코어       NaN     NaN          NaN
# 3420212  0.0(ncp) 2022-02-02         웍스코어       NaN     NaN          NaN
# 3420213  0.0(ncp) 2022-02-02         웍스코어       NaN     NaN          NaN
# 3420214  0.0(ncp) 2022-04-27         웍스코어       0.0       -            -
# 3420215  0.0(ncp) 2022-04-27         웍스코어       0.0       -            -
# 3420216  0.0(ncp) 2022-04-27         웍스코어       0.0       -            -
# 3420217  0.0(ncp) 2022-04-27         웍스코어       0.0       -            -
# ...

# %%
merged_base = merged_base[merged_base['domainId']!='0.0(ncp)']

# %%
merged_base.to_csv('/Users/user/Documents/진행중 업무/base_integrated_data.csv',index=False)

# %%
from datetime import datetime

option['item_group'] = option['item_id']
option.loc[option['item_id']=='ACV','item_group'] = '메세지 아카이빙'
option.loc[option['item_id']=='SSTG','item_group'] = '추가 공용용량'
option.loc[option['item_id']=='OCE1','item_group'] = '웍스코어 공동편집'
option.loc[option['item_id']=='OCE2','item_group'] = '드라이브 공동편집'
option.loc[option['item_id']=='QTA_O','item_group'] = '클로바노트 추가쿼터(갱신)'
option.loc[option['item_id']=='QTA_M','item_group'] = '클로바노트 추가쿼터(1회)'
option.loc[option['item_id']=='TXI','item_group'] = '결재 세금계산서'
option.loc[option['item_id']=='PLG','item_group'] = '결재 서약서'
option.loc[option['item_id']=='RSV','item_group'] = '결재 예약'
option.loc[option['item_id']=='COC','item_group'] = '재무 법인카드 연동'
option.loc[option['item_id'].isin(['ACV4','ACV5']),'item_group'] = '웍스코어 공용용량'
option = option.copy()
option['odPartnerStatus'] = np.where(option['seller_id']==0,'OD','Partner')
option['calc_ymd'] = pd.to_datetime(option['calc_ymd'])
start_date = datetime(2023, 1, 1)
option['date_code'] = (option['calc_ymd'] - start_date).dt.days + 91
option.loc[option['calc_ymd'].astype(str).str[0:4] =='2022','date_code'] = option['calc_ymd'].astype(str).str[5:7].astype(int) * 7
option
# Out:
#          member_no           item_group              item_id   calc_ymd  \
# 0        2716896.0     WORKPLACE 연동법인카드     WORKPLACE 연동법인카드 2022-01-26
# 1        2527130.0     WORKPLACE 연동법인카드     WORKPLACE 연동법인카드 2022-01-26
# 2        2669296.0         Workbox 공용용량         Workbox 공용용량 2022-01-26
# 3        2618879.0     WORKPLACE 연동법인카드     WORKPLACE 연동법인카드 2022-01-26
# 4        2597299.0         Workbox 공용용량         Workbox 공용용량 2022-01-26
# ...            ...                  ...                  ...        ...
# 4690920  3302861.0  WORKBOX Paid Volume  WORKBOX Paid Volume 2024-11-03
# 4690921  3302861.0  WORKBOX Paid Volume  WORKBOX Paid Volume 2024-11-04
# 4690922  3302861.0  WORKBOX Paid Volume  WORKBOX Paid Volume 2024-11-05
# 4690923  3302861.0  WORKBOX Paid Volume  WORKBOX Paid Volume 2024-11-06
# 4690924  3302861.0  WORKBOX Paid Volume  WORKBOX Paid Volume 2024-11-07
#
#          user_count testdomainYn ncpIdYn       domain_id  tenant_id  \
# ...

# %%
option_add_days = option.copy()
rows_to_duplicate = option_add_days[option_add_days['date_code'] == 84]
duplicated_rows = pd.concat(
    [rows_to_duplicate.assign(date_code=code) for code in range(85, 91)],
    ignore_index=True
)
option_add_days = pd.concat([option_add_days, duplicated_rows], ignore_index=True)
option_add_days['date_code'] = option_add_days['date_code'] + 7
option_add_days
# Out:
#          member_no             item_group                item_id   calc_ymd  \
# 0        2716896.0       WORKPLACE 연동법인카드       WORKPLACE 연동법인카드 2022-01-26
# 1        2527130.0       WORKPLACE 연동법인카드       WORKPLACE 연동법인카드 2022-01-26
# 2        2669296.0           Workbox 공용용량           Workbox 공용용량 2022-01-26
# 3        2618879.0       WORKPLACE 연동법인카드       WORKPLACE 연동법인카드 2022-01-26
# 4        2597299.0           Workbox 공용용량           Workbox 공용용량 2022-01-26
# ...            ...                    ...                    ...        ...
# 4693440  2552351.0  Workbox Online Editor  Workbox Online Editor 2022-12-28
# 4693441  2745040.0  Workbox Online Editor  Workbox Online Editor 2022-12-28
# 4693442  1702545.0  Workbox Online Editor  Workbox Online Editor 2022-12-28
# 4693443  2918557.0  Workbox Online Editor  Workbox Online Editor 2022-12-28
# 4693444  2791109.0  Workbox Online Editor  Workbox Online Editor 2022-12-28
#
# ...

# %%
option['domain_id_num'] = option['domain_id'].astype(str).str.split('(').str[0].astype(float).astype(int)
option_add_days['domain_id_num'] = option_add_days['domain_id'].astype(str).str.split('(').str[0].astype(float).astype(int)

# %%
percentile_thresholds = []
for i in range(10, 101, 10):
    percentile_value = option['domain_id_num'].quantile(i / 100)
    percentile_thresholds.append(percentile_value)

percentile_thresholds
# Out:
# [94165.0,
#  138667.0,
#  183634.0,
#  2985874.0,
#  300054104.0,
#  300120184.0,
#  300153594.0,
#  300164002.0,
#  300173703.0,
#  300186703.0]

# %%
option0 = option[(option['domain_id_num'].isna())]
option1 = option[(option['domain_id_num']<=percentile_thresholds[0])]
option2 = option[(option['domain_id_num']<=percentile_thresholds[1])&(option['domain_id_num']>percentile_thresholds[0])]
option3 = option[(option['domain_id_num']<=percentile_thresholds[2])&(option['domain_id_num']>percentile_thresholds[1])]
option4 = option[(option['domain_id_num']<=percentile_thresholds[3])&(option['domain_id_num']>percentile_thresholds[2])]
option5 = option[(option['domain_id_num']<=percentile_thresholds[4])&(option['domain_id_num']>percentile_thresholds[3])]
option6 = option[(option['domain_id_num']<=percentile_thresholds[5])&(option['domain_id_num']>percentile_thresholds[4])]
option7 = option[(option['domain_id_num']<=percentile_thresholds[6])&(option['domain_id_num']>percentile_thresholds[5])]
option8 = option[(option['domain_id_num']<=percentile_thresholds[7])&(option['domain_id_num']>percentile_thresholds[6])]
option9 = option[(option['domain_id_num']<=percentile_thresholds[8])&(option['domain_id_num']>percentile_thresholds[7])]
option10 = option[(option['domain_id_num']>percentile_thresholds[8])]

option_add_days1 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[0])]
option_add_days2 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[1])&(option_add_days['domain_id_num']>percentile_thresholds[0])]
option_add_days3 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[2])&(option_add_days['domain_id_num']>percentile_thresholds[1])]
option_add_days4 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[3])&(option_add_days['domain_id_num']>percentile_thresholds[2])]
option_add_days5 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[4])&(option_add_days['domain_id_num']>percentile_thresholds[3])]
option_add_days6 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[5])&(option_add_days['domain_id_num']>percentile_thresholds[4])]
option_add_days7 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[6])&(option_add_days['domain_id_num']>percentile_thresholds[5])]
option_add_days8 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[7])&(option_add_days['domain_id_num']>percentile_thresholds[6])]
option_add_days9 = option_add_days[(option_add_days['domain_id_num']<=percentile_thresholds[8])&(option_add_days['domain_id_num']>percentile_thresholds[7])]
option_add_days10 = option_add_days[(option_add_days['domain_id_num']>percentile_thresholds[8])]

# %%
merged_option1 = pd.merge(
    option1, option_add_days1,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option2 = pd.merge(
    option2, option_add_days2,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option3 = pd.merge(
    option3, option_add_days3,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option4 = pd.merge(
    option4, option_add_days4,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option5 = pd.merge(
    option5, option_add_days5,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option6 = pd.merge(
    option6, option_add_days6,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option7 = pd.merge(
    option7, option_add_days7,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option8 = pd.merge(
    option8, option_add_days8,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option9 = pd.merge(
    option9, option_add_days9,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)
merged_option10 = pd.merge(
    option10, option_add_days10,
    how='outer',
    on=['domain_id', 'date_code', 'item_group','item_id'],
    suffixes=('_cr', '_bf')
)

# %%
option0 = option0.rename(columns = {'calc_ymd':'calc_ymd_cr','member_no':'member_no_cr','user_count':'user_count_cr','testdomainYn':'testdomainYn_cr','ncpIdYn':'ncpIdYn_cr','tenant_id':'tenant_id_cr','seller_id':'seller_id_cr','pmnt_plan_start_ymd':'pmnt_plan_start_ymd_cr','pmnt_plan_end_ymd':'pmnt_plan_end_ymd_cr','odPartnerStatus':'odPartnerStatus_cr','groupType':'groupType_cr'})
merged_option = pd.concat([option0, merged_option1, merged_option2, merged_option3, merged_option4, merged_option5, merged_option6, merged_option7, merged_option8, merged_option9, merged_option10])
merged_option['calc_ymd_bf'] = merged_option['calc_ymd_bf'] + timedelta(days=7)
merged_option['calc_ymd_cr'] = merged_option['calc_ymd_cr'].fillna(merged_option['calc_ymd_bf'])
merged_option = merged_option[~merged_option['date_code'].between(85, 90)]
columns_to_move = ['domain_id', 'calc_ymd_cr', 'item_group','item_id']
merged_option = merged_option[columns_to_move + [col for col in merged_option.columns if col not in columns_to_move]]

# %%
merged_option = merged_option.drop(['date_code','calc_ymd_bf','domain_id_num_cr','domain_id_num_bf'],axis=1)
merged_option = merged_option.rename(columns = {'domain_id':'domainId','calc_ymd_cr':'date','item_group':'optionproductGroup','member_no_cr':'cr_ncpId','member_no_bf':'bf_ncpId','item_id':'option',
                                            'user_count_cr':'cr_optUserCount','user_count_bf':'bf_optUserCount','testdomainYn_cr':'cr_testdomainyn','testdomainYn_bf':'bf_testdomainyn','tenant_id_cr':'cr_tenantId','tenant_id_bf':'bf_tenantId',
                                            'seller_id_cr':'cr_partnerDomainId','seller_id_bf':'bf_partnerDomainId','pmnt_plan_start_ymd_cr':'cr_optPaymentPlanStartDate','pmnt_plan_start_ymd_bf':'bf_optPaymentPlanStartDate',
                                            'pmnt_plan_end_ymd_cr':'cr_optPaymentPlanEndDate','pmnt_plan_end_ymd_bf':'bf_optPaymentPlanEndDate','ncpIdYn_cr':'cr_ncpIdYn','ncpIdYn_bf':'bf_ncpIdYn','odPartnerStatus_cr':'cr_odPartnerStatus','odPartnerStatus_bf':'bf_odPartnerStatus'})

# %%
merged_option
# Out:
#            domainId       date optionproductGroup option   cr_ncpId  \
# 0               7.0 2024-07-01          웍스코어 공용용량   ACV4        NaN
# 1               7.0 2024-07-01          웍스코어 공용용량   ACV5        NaN
# 2               7.0 2024-07-02          웍스코어 공용용량   ACV4        NaN
# 3               7.0 2024-07-02          웍스코어 공용용량   ACV5        NaN
# 4               7.0 2024-07-03          웍스코어 공용용량   ACV4        NaN
# ...             ...        ...                ...    ...        ...
# 616053  300186701.0 2025-01-07          웍스코어 공용용량   ACV5        NaN
# 616054  300186703.0 2024-12-31          웍스코어 공용용량   ACV4  3451206.0
# 616055  300186703.0 2024-12-31          웍스코어 공용용량   ACV5  3451206.0
# 616056  300186703.0 2025-01-07          웍스코어 공용용량   ACV4        NaN
# 616057  300186703.0 2025-01-07          웍스코어 공용용량   ACV5        NaN
#
#         cr_optUserCount cr_testdomainyn cr_ncpIdYn  cr_tenantId  \
# 0               11660.0               Y          N          7.0
# ...

# %%
merged_option.to_csv('/Users/user/Documents/진행중 업무/option_integrated_data.csv',index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.rcParams['font.family'] = 'AppleGothic'

# %%
merged_base = pd.read_csv('/Users/user/Documents/진행중 업무/base_integrated_data.csv')
merged_option = pd.read_csv('/Users/user/Documents/진행중 업무/option_integrated_data.csv')
# Out:
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_46836/3347155151.py:1: DtypeWarning: Columns (0,9,10,11,21,22,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_base = pd.read_csv('/Users/user/Documents/진행중 업무/base_integrated_data.csv')
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_46836/3347155151.py:2: DtypeWarning: Columns (0,9,10,11,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_option = pd.read_csv('/Users/user/Documents/진행중 업무/option_integrated_data.csv')

# %%
merged_base['plan_prefix'] = merged_base['plan_cr'].str[:3]

def preprocess3(df):
    conversion_row = df[df['groupType_cr'] == 'Paid'].sort_values('date').head(1)
    if not conversion_row.empty:
        conversion_date = conversion_row.iloc[0]['date']
        df['전환여부'] = 'Y'
        df['전환일'] = conversion_date
    else:
        df['전환여부'] = 'N'
        df['전환일'] = None
    return df

empty_prefix_rows = merged_base[merged_base['plan_prefix'].isna() | (merged_base['plan_prefix'] == '')]
empty_prefix_rows['전환여부'] = None
empty_prefix_rows['전환일'] = None

non_empty_prefix_rows = merged_base[~(merged_base['plan_prefix'].isna() | (merged_base['plan_prefix'] == ''))]
processed_rows = non_empty_prefix_rows.groupby(['domainId', 'plan_prefix'], group_keys=False).apply(preprocess3)

merged_base = pd.concat([empty_prefix_rows, processed_rows], ignore_index=True)
merged_base
# Out:
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_46836/390935086.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_prefix_rows['전환여부'] = None
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_46836/390935086.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   empty_prefix_rows['전환일'] = None
# ...

# %%
def preprocess4 (df) :

    df['전환여부'] = np.where(df['groupType_cr'].isin(['Paid','Free']), np.nan, df['전환여부'])
    df['전환일'] = np.where(df['groupType_cr'].isin(['Paid','Free']), np.nan, df['전환일'])

    return df

merged_base = preprocess4(merged_base)

# %%
merged_base = merged_base.drop(['plan_prefix'],axis=1)
columns_to_move = ['domainId', 'date', 'productGroup','전환여부','전환일']
merged_base = merged_base[columns_to_move + [col for col in merged_base.columns if col not in columns_to_move]]
merged_base
# Out:
#              domainId        date productGroup  전환여부   전환일   ncpId_cr plan_cr  \
# 0                 7.0  2024-10-15         웍스코어  None  None        NaN     NaN
# 1                 7.0  2024-10-16         웍스코어  None  None        NaN     NaN
# 2                 7.0  2025-01-01         웍스코어  None  None        NaN     NaN
# 3                 7.0  2025-01-02         웍스코어  None  None        NaN     NaN
# 4                 7.0  2025-01-03         웍스코어  None  None        NaN     NaN
# ...               ...         ...          ...   ...   ...        ...     ...
# 45876003  300149777.0  2024-05-29         웍스코어   NaN   NaN  3341966.0      FR
# 45876004  300149778.0  2024-05-29         웍스코어   NaN   NaN  3198870.0      FR
# 45876005  300149779.0  2024-05-29         웍스코어   NaN   NaN  3335416.0      FR
# 45876006  300149780.0  2024-05-29         웍스코어   NaN   NaN  3341974.0      FR
# 45876007  300149781.0  2024-05-29         웍스코어   NaN   NaN  3341978.0      FR
#
# ...

# %%
merged_base.to_csv('/Users/user/Documents/진행중 업무/base_integrated_data_전환정보포함.csv', index=False)

# %%
# christmas counts

# %%
merged_base1 = merged_base[(merged_base['ncpIdYn_cr']=='Y')&(merged_base['testdomainyn_cr']=='N')]
merged_base1 = merged_base1[~merged_base1['ncpId_cr'].isin([2895255,3060425,3148940,3060396])]

# %%
christmas = merged_base1[merged_base1['date'].astype(str)=='2024-12-25']
christmas = christmas[~christmas['plan_cr'].isna()]

# %%
result = christmas.groupby('plan_cr').agg(
    row_count=('plan_cr', 'count'),
    userCount_cr_sum=('userCount_cr', 'sum')
).reset_index()

result
# Out:
#       plan_cr  row_count  userCount_cr_sum
# 0     APP_STD       2393           59371.0
# 1       APP_T         66            1819.0
# 2     ATT_STD       2042           52332.0
# 3       ATT_T         46             664.0
# 4      CNT_BZ          2               5.0
# 5      CNT_LT         11             138.0
# 6       CNT_T         19             515.0
# 7      CNT_TM          8             872.0
# 8      COR_FR        131            1296.0
# 9      COR_LT       1146           54562.0
# 10    COR_STD      21937          204728.0
# 11  COR_STD_P       5588           79991.0
# 12      COR_T         66             271.0
# 13     DRV_LT        167            1306.0
# 14    DRV_STD        141             650.0
# 15  DRV_STD_P        341            2584.0
# 16      DRV_T         33             200.0
# 17    FIN_STD       1683           44769.0
# 18      FIN_T         20             137.0
# 19    PAY_STD        189            4483.0
# 20      PAY_T         12             138.0
# ...

# %%
result.to_excel('/Users/user/Documents/진행중 업무/plan_counts.xlsx',index=False)

# %%
#pivot transition

# %%
merged_base = pd.read_csv('/Users/user/Documents/진행중 업무/base_integrated_data_전환정보포함.csv')
merged_option = pd.read_csv('/Users/user/Documents/진행중 업무/option_integrated_data.csv')
# Out:
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_18470/833126514.py:1: DtypeWarning: Columns (0,3,4,11,12,13,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_base = pd.read_csv('/Users/user/Documents/진행중 업무/base_integrated_data_전환정보포함.csv')
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_18470/833126514.py:2: DtypeWarning: Columns (0,9,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_option = pd.read_csv('/Users/user/Documents/진행중 업무/option_integrated_data.csv')

# %%
merged_base = merged_base.drop(['전환여부','전환일'],axis=1)

# %%
def join_values(values):
    return ', '.join(map(str, values))

pivot = merged_base.pivot_table(
    index=['domainId', 'date'],
    columns='productGroup',
    values='plan_cr',
    aggfunc=lambda x: join_values(x)
).reset_index()

pivot.columns.name = None
pivot = pivot.rename_axis(None, axis=1)

pivot
# Out:
#          domainId        date  STG  WLS 경영지원   근태   급여 드라이브   웍스코어   재무 클로바노트
# 0             7.0  2024-06-04  NaN  NaN  NaN  NaN  NaN  NaN  COR_T  NaN   NaN
# 1             7.0  2024-06-05  NaN  NaN  NaN  NaN  NaN  NaN  COR_T  NaN   NaN
# 2             7.0  2024-06-06  NaN  NaN  NaN  NaN  NaN  NaN  COR_T  NaN   NaN
# 3             7.0  2024-06-07  NaN  NaN  NaN  NaN  NaN  NaN  COR_T  NaN   NaN
# 4             7.0  2024-06-08  NaN  NaN  NaN  NaN  NaN  NaN  COR_T  NaN   NaN
# ...           ...         ...  ...  ...  ...  ...  ...  ...    ...  ...   ...
# 40028844   9957.0  2024-06-17  NaN  NaN  NaN  NaN  NaN  NaN    nan  NaN   NaN
# 40028845   9957.0  2024-06-18  NaN  NaN  NaN  NaN  NaN  NaN    nan  NaN   NaN
# 40028846   9957.0  2024-06-19  NaN  NaN  NaN  NaN  NaN  NaN    nan  NaN   NaN
# 40028847   9957.0  2024-06-20  NaN  NaN  NaN  NaN  NaN  NaN    nan  NaN   NaN
# 40028848   9957.0  2024-06-21  NaN  NaN  NaN  NaN  NaN  NaN    nan  NaN   NaN
#
# [40028849 rows x 11 columns]

# %%
merged_base1 = merged_base.drop('productGroup', axis = 1)
merged_base2 = pd.merge(merged_base1, pivot, on = ['domainId','date'], how = 'left')
merged_base2
# Out:
#          domainId        date  ncpId_cr plan_cr  userCount_cr testdomainyn_cr  \
# 0             7.0  2024-06-04       NaN   COR_T       11686.0             NaN
# 1             7.0  2024-06-05       NaN   COR_T       11686.0             NaN
# 2             7.0  2024-06-06       NaN   COR_T       11686.0             NaN
# 3             7.0  2024-06-07       NaN   COR_T       11686.0             NaN
# 4             7.0  2024-06-08       NaN   COR_T       11686.0             NaN
# ...           ...         ...       ...     ...           ...             ...
# 44341469   9957.0  2024-06-17       NaN     NaN           NaN             NaN
# 44341470   9957.0  2024-06-18       NaN     NaN           NaN             NaN
# 44341471   9957.0  2024-06-19       NaN     NaN           NaN             NaN
# 44341472   9957.0  2024-06-20       NaN     NaN           NaN             NaN
# 44341473   9957.0  2024-06-21       NaN     NaN           NaN             NaN
#
# ...

# %%
def clean_comma_separated(value):
    if pd.isna(value):
        return value
    return ','.join(sorted(set(x.strip() for x in value.split(',') if x.strip().lower() != 'nan')))

merged_base2['웍스코어'] = merged_base2['웍스코어'].apply(clean_comma_separated)
merged_base2['드라이브'] = merged_base2['드라이브'].apply(clean_comma_separated)
merged_base2['경영지원'] = merged_base2['경영지원'].apply(clean_comma_separated)
merged_base2['근태'] = merged_base2['근태'].apply(clean_comma_separated)
merged_base2['재무'] = merged_base2['재무'].apply(clean_comma_separated)
merged_base2['급여'] = merged_base2['급여'].apply(clean_comma_separated)
merged_base2['클로바노트'] = merged_base2['클로바노트'].apply(clean_comma_separated)
merged_base2['WLS'] = merged_base2['WLS'].apply(clean_comma_separated)
merged_base2['STG'] = merged_base2['STG'].apply(clean_comma_separated)

# %%
merged_base2.to_csv('/Users/user/Documents/진행중 업무/base_integrated_data_pivot.csv', index=False)

# %%
def join_values(values):
    return ', '.join(map(str, values))

pivot = merged_option.pivot_table(
    index=['domainId', 'date'],
    columns='optionproductGroup',
    values='option',
    aggfunc=lambda x: join_values(x)
).reset_index()

pivot.columns.name = None
pivot = pivot.rename_axis(None, axis=1)

pivot
# Out:
#         domainId        date NAVER WORKS ARCHIVING NAVER WORKS VOLUME  \
# 0            7.0  2024-06-04                   NaN                NaN
# 1            7.0  2024-06-05                   NaN                NaN
# 2            7.0  2024-06-06                   NaN                NaN
# 3            7.0  2024-06-07                   NaN                NaN
# 4            7.0  2024-06-08                   NaN                NaN
# ...          ...         ...                   ...                ...
# 2671744  93716.0  2024-06-15                   NaN                NaN
# 2671745  93716.0  2024-06-16                   NaN                NaN
# 2671746  93716.0  2024-06-17                   NaN                NaN
# 2671747  93716.0  2024-06-18                   NaN                NaN
# 2671748  93716.0  2024-06-19                   NaN                NaN
#
#         WORKBOX Paid Volume WORKPLACE AI OCR WORKPLACE 공용용량  \
# 0                       NaN              NaN            NaN
# ...

# %%
merged_option1 = merged_option.drop('optionproductGroup', axis = 1)
merged_option2 = pd.merge(merged_option1, pivot, on = ['domainId','date'], how = 'left')
merged_option2
# Out:
#         domainId        date option  cr_ncpId  cr_optUserCount  \
# 0            7.0  2024-06-04   ACV4       NaN          11686.0
# 1            7.0  2024-06-04   ACV5       NaN          11686.0
# 2            7.0  2024-06-05   ACV4       NaN          11686.0
# 3            7.0  2024-06-05   ACV5       NaN          11686.0
# 4            7.0  2024-06-06   ACV4       NaN          11686.0
# ...          ...         ...    ...       ...              ...
# 5213315  94165.0  2025-01-03   ACV5       NaN              NaN
# 5213316  94165.0  2025-01-04   ACV4       NaN              NaN
# 5213317  94165.0  2025-01-04   ACV5       NaN              NaN
# 5213318  94165.0  2025-01-05   ACV4       NaN              NaN
# 5213319  94165.0  2025-01-05   ACV5       NaN              NaN
#
#         cr_testdomainyn cr_ncpIdYn  cr_tenantId cr_partnerDomainId  \
# 0                     Y          N          7.0                0.0
# 1                     Y          N          7.0                0.0
# ...

# %%
def clean_comma_separated(value):
    if pd.isna(value):
        return value
    return ','.join(sorted(set(x.strip() for x in value.split(',') if x.strip().lower() != 'nan')))

merged_option2['웍스코어 공용용량'] = merged_option2['웍스코어 공용용량'].apply(clean_comma_separated)

# %%
merged_option2.to_csv('/Users/user/Documents/진행중 업무/option_integrated_data_pivot.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
plt.rcParams['font.family'] = 'AppleGothic'

# %%
merged_base = pd.read_csv('/Users/user/Documents/진행중 업무/base_integrated_data_전환정보포함.csv')
merged_option = pd.read_csv('/Users/user/Documents/진행중 업무/option_integrated_data.csv')
# Out:
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_18998/3980703944.py:1: DtypeWarning: Columns (0,3,4,6,8,9,11,12,13,14,15,23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_base = pd.read_csv('/Users/user/Documents/진행중 업무/base_integrated_data_전환정보포함.csv')

# %%
merged_base2 = pd.read_csv('/Users/user/Documents/진행중 업무/base_integrated_data_pivot.csv')
merged_option2 = pd.read_csv('/Users/user/Documents/진행중 업무/option_integrated_data_pivot.csv')
# Out:
# /var/folders/yj/y3b7nzyn7zv0l9bkqtj_37g40000gn/T/ipykernel_18998/32779076.py:1: DtypeWarning: Columns (0,4,8,9,10,16,20,21,22,25,26,27,28,29,30,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_base2 = pd.read_csv('/Users/user/Documents/진행중 업무/base_integrated_data_pivot.csv')

# %%
merged_base = merged_base[merged_base['domainId']!='0.0(ncp)']
merged_base['domainId'] = merged_base['domainId'].apply(
    lambda x: str(x).replace('.0', '') if isinstance(x, str) and x.endswith('(ncp)') else x
)
merged_base = merged_base.sort_values(by = ['domainId','date','productGroup'])
merged_base = merged_base.drop_duplicates(subset = ['domainId','date','productGroup'], keep = 'last')
merged_base.to_csv('/Users/user/Documents/진행중 업무/base_integrated_data_전환정보포함.csv', index=False)

# %%
merged_option = merged_option[merged_option['domainId']!='0.0(ncp)']
merged_option['domainId'] = merged_option['domainId'].apply(
    lambda x: str(x).replace('.0', '') if isinstance(x, str) and x.endswith('(ncp)') else x
)
merged_option = merged_option.sort_values(by = ['domainId','date','option'])
merged_option = merged_option.drop_duplicates(subset = ['domainId','date','option'], keep = 'last')
merged_option.to_csv('/Users/user/Documents/진행중 업무/option_integrated_data.csv', index=False)

# %%
merged_base2 = merged_base2[merged_base2['domainId']!='0.0(ncp)']
merged_base2['domainId'] = merged_base2['domainId'].apply(
    lambda x: str(x).replace('.0', '') if isinstance(x, str) and x.endswith('(ncp)') else x
)
merged_base2.to_csv('/Users/user/Documents/진행중 업무/base_integrated_data_pivot.csv', index=False)

# %%
merged_option2 = merged_option2[merged_option2['domainId']!='0.0(ncp)']
merged_option2['domainId'] = merged_option2['domainId'].apply(
    lambda x: str(x).replace('.0', '') if isinstance(x, str) and x.endswith('(ncp)') else x
)
merged_option2.to_csv('/Users/user/Documents/진행중 업무/option_integrated_data_pivot.csv', index=False)
